# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### **Testing**

# %%
url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p=1&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
response = requests.get(url, headers=headers)

# %%
if response.status_code == 200: # Check if the request was successful. If the status code is 200, it means successful.
    soup = BeautifulSoup(response.text, 'html.parser')
    print(soup.prettify())  # Print formatted HTML to see the content
else:
    print("Failed to retrieve the page.")
# Out:
# <!DOCTYPE html>
# <html>
#  <head id="hdBase">
#   <meta charset="utf-8"/>
#   <title>
#    BWF - BWF World Rankings - Overview
#   </title>
#   <meta content="tournamentsoftware.com: Software to run tournaments, leagues and ladders for tennis, badminton, padel, squash and other racket sports" name="description"/>
#   <meta content="tennis, tournament, planner, tennis, amateur tennis, software, tournamentplanner, register, sport, www.tournamentsoftware.com, www.tournament.com, www.tennistournament.com, www.tennistoernooi.com, register, squash, badminton, entry, tournament, planner, tournooi, tournament, volleybal, volleyball, association, planning, poule, draw, tennis software, match, poule, match overview, teamsport, team, official, teamsportplanner, hockey, basketball, competition, league" name="keywords"/>
#   <link href="//static.tournamentsoftware.com/content/images/themes/bwf/app/favicon.ico?v=20170126155446" rel="shortcut icon" type="image/icon"/>
#   <link href="../content/images/themes/bwf/app/manifest.json" rel="manifest"/>
#   <meta content="Copyright 2000-2024 Visual Reality" name="copyright"/>
#   <script async="true" src="https://www.googletagmanager.com/gtag/js?id=G-X6MH3T0B6G">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag('js', new Date());gtag('config', 'G-X6MH3T0B6G');
#   </script>
#   <meta content="noindex,nofollow" name="robots"/>
#   <link href="/VisualResource.ashx?id=75416e5f5fbd16cf091b02dd563f0b1e" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/VisualResource.ashx?id=c372b688d39ca9078e6c11167619c523" media="print" rel="stylesheet" type="text/css"/>
#   <link href="//static.tournamentsoftware.com/content/styles/css/themes/bwf/styles.css?v=20241008104913" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//static.tournamentsoftware.com/content/styles/css/themes/bwf/styles-legacy.css?v=20240109081637" media="all" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="layout-is-old organization organization--bwf" id="bdBase">
#   <form action="./category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=1&amp;ps=100" class="chosendd hasbanner bwf_logo lcid1033 rankingpage rid70" id="formBasePage" method="post">
#    <div class="aspNetHidden">
#     <input id="__EVENTTARGET" name="__EVENTTARGET" type="hidden" value=""/>
#     <input id="__EVENTARGUMENT" name="__EVENTARGUMENT" type="hidden" value=""/>
#     <input id="__LASTFOCUS" name="__LASTFOCUS" type="hidden" value=""/>
#     <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="YoivDwGqKzUgphYB1A5AgAIV++jd7FmKDhxyTZHBM1jVjYCc0QcshfqFIhbn53UPDhDxh3sW/8D5u69BtNIrNSHEsMg="/>
#    </div>
#    <script type="text/javascript">
#     //<![CDATA[
# var theForm = document.forms['formBasePage'];
# if (!theForm) {
#     theForm = document.formBasePage;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
#    </script>
#    <script src="/VisualResource.ashx?id=a7c57f7f4c17316c16296650f8a7a92d" type="text/javascript">
#    </script>
#    <script src="//static.tournamentsoftware.com/Content/scripts/dist/vendorold-bundle.js?v=20220607100246" type="text/javascript">
#    </script>
#    <script src="//static.tournamentsoftware.com/Content/scripts/dist/functions_legacy-bundle.js?v=20240917102256" type="text/javascript">
#    </script>
#    <div class="aspNetHidden">
#     <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="AC269323"/>
#     <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
#    </div>
#    <input aria-haspopup="true" class="accessible-hidden menu__toggle" id="nav-toggle" role="button" type="checkbox"/>
#    <input aria-haspopup="true" class="accessible-hidden menu__toggle" id="tertiary-nav-toggle" role="button" type="checkbox"/>
#    <input aria-haspopup="true" class="is-extendable-until-medium accessible-hidden" id="sidebar-toggle" role="button" type="checkbox"/>
#    <nav class="primary-nav" role="navigation">
#     <label class="nav-toggle__button menu__button js-nav-toggle__button" for="nav-toggle" title="Click to hide site navigation">
#      <span class="nav-toggle__title">
#       Menu
#      </span>
#      <span class="hamburger">
#      </span>
#     </label>
#     <h1 class="logo">
#      <a class="logo__link" href="/">
#       <img alt="BWF" id="logo--desktop" src="//static.tournamentsoftware.com/Content/images/themes/bwf/logo.svg?v=20180501132712"/>
#       <span class="logo__name">
#        BWF
#       </span>
#      </a>
#     </h1>
#     <ul>
#      <li class="primary-nav__wrapper">
#       <ul class="primary-nav__list">
#        <li class="primary-nav__item">
#         <a class="primary-nav__link nav-link" href="/" title="Home">
#          <svg aria-hidden="true" class="icon-home nav-link__prefix" height="20" width="20">
#           <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-home">
#           </use>
#          </svg>
#          <span class="nav-link__value">
#           Home
#          </span>
#         </a>
#        </li>
#        <li class="primary-nav__item">
#         <a class="primary-nav__link nav-link" href="/tournaments" title="Tournaments">
#          <svg aria-hidden="true" class="icon-tournament nav-link__prefix" height="20" width="20">
#           <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-tournament">
#           </use>
#          </svg>
#          <span class="nav-link__value">
#           Tournaments
#          </span>
#         </a>
#        </li>
#        <li class="primary-nav__item">
#         <a class="primary-nav__link nav-link" href="/find/player" title="Players">
#          <svg aria-hidden="true" class="icon-players nav-link__prefix" height="20" width="20">
#           <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-players">
#           </use>
#          </svg>
#          <span class="nav-link__value">
#           Players
#          </span>
#         </a>
#        </li>
#        <li class="primary-nav__item">
#         <a aria-current="page" class="primary-nav__link nav-link is-active" href="/ranking" title="Ranking">
#          <svg aria-hidden="true" class="icon-statistics nav-link__prefix" height="20" width="20">
#           <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-statistics">
#           </use>
#          </svg>
#          <span class="nav-link__value">
#           Ranking
#          </span>
#         </a>
#        </li>
#        <li class="primary-nav__item">
#         <button aria-controls="clps_81cb3a1c14b84bfdb360d68aa9785136" aria-expanded="false" aria-haspopup="true" class="primary-nav__link nav-link" data-target="#clps_81cb3a1c14b84bfdb360d68aa9785136" data-toggle="collapse" title="LiveScore" type="button">
#          <svg aria-hidden="true" class="icon-livescore nav-link__prefix" height="20" width="20">
#           <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-livescore">
#           </use>
#          </svg>
#          <span class="nav-link__value">
#           LiveScore
#          </span>
#          <span class="nav-link__postfix tag tag--soft">
#           5
#          </span>
#          <svg aria-hidden="true" class="icon-dropdown nav-link__postfix" height="20" width="20">
#           <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-dropdown">
#           </use>
#          </svg>
#         </button>
#         <ul aria-hidden="true" aria-label="submenu" class="primary-nav__list collapse" data-parent-title="LiveScore" id="clps_81cb3a1c14b84bfdb360d68aa9785136">
#          <li class="primary-nav__item">
#           <a class="primary-nav__link nav-link" href="/sport/tournament.aspx?id=9D25A0EB-AC1C-43E6-B02A-9AF6B10E5B4D">
#            <span class="nav-link__value" title="YONEX BWF World Junior Championships 2024">
#             YONEX BWF World Junior Championships 2024
#            </span>
#           </a>
#          </li>
#          <li class="primary-nav__item">
#           <a class="primary-nav__link nav-link" href="/sport/tournament.aspx?id=141A5C6E-7E62-4643-9952-BF76D5DF28FA">
#            <span class="nav-link__value" title="CLASH ROYALE Arctic Open 2024 powered by YONEX">
#             CLASH ROYALE Arctic Open 2024 powered by YONEX
#            </span>
#           </a>
#          </li>
#          <li class="primary-nav__item">
#           <a class="primary-nav__link nav-link" href="/sport/tournament.aspx?id=F521B97C-FD6D-4626-88E2-8B3BD48DE049">
#            <span class="nav-link__value" title="YONEX Bendigo International 2024">
#             YONEX Bendigo International 2024
#            </span>
#           </a>
#          </li>
#          <li class="primary-nav__item">
#           <a class="primary-nav__link nav-link" href="/sport/tournament.aspx?id=497A05B2-5643-4B56-AF15-381610E364FD">
#            <span class="nav-link__value" title="YONEX German Ruhr U17 International 2024">
#             YONEX German Ruhr U17 International 2024
#            </span>
#           </a>
#          </li>
#          <li class="primary-nav__item">
#           <a class="primary-nav__link nav-link" href="/sport/tournament.aspx?id=0ACA70E1-F484-4880-882C-B395E4C85AA4">
#            <span class="nav-link__value" title="YONEX German Ruhr U19 International 2024">
#             YONEX German Ruhr U19 International 2024
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </li>
#      <li class="primary-nav__wrapper">
#       <ul class="primary-nav__list primary-nav__list--sub">
#        <li class="primary-nav__item">
#         <a class="primary-nav__link nav-link js-asyncmodal" data-modal-class="modal-sm" href="/language/setlanguage?returnUrl=%2Franking%2Fcategory.aspx%3Fid%3D42511%26category%3D472%26C472FOC%3D%26p%3D1%26ps%3D100">
#          <img class="icon-lang" src="//static.tournamentsoftware.com/content/images/flags/USA.svg"/>
#          <span class="nav-link__value">
#           English
#          </span>
#         </a>
#        </li>
#       </ul>
#      </li>
#     </ul>
#    </nav>
#    <div class="content">
#     <div class="masthead" role="banner">
#      <div class="masthead__main">
#       <label class="nav-toggle__button masthead__item-link menu__button" for="nav-toggle" title="Click to show site navigation">
#        <span class="nav-toggle__title">
#         Menu
#        </span>
#        <span class="hamburger">
#        </span>
#       </label>
#       <label class="masthead__item-link" for="MastheadSearchInput">
#        <svg aria-hidden="true" class="icon-search margin-right--small" height="20" width="20">
#         <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-search">
#         </use>
#        </svg>
#        <span class="-l-visible-inline-block -xl-visible-inline-block">
#         Search
#        </span>
#       </label>
#       <div class="main-search-initialy-hidden-container">
#        <div class="search__main">
#         <div class="search-box">
#          <div class="form-has-icon has-clear js-form-wrapper form-wrapper">
#           <div class="form-element">
#            <input aria-describedby="SearchString-tip" autocapitalize="off" autocomplete="off" autocorrect="off" class="form-control search-box__field js-search-box__field" data-min-char="3" id="MastheadSearchInput" name="SearchString" placeholder="Search" spellcheck="false" type="search"/>
#            <span class="placeholder-text">
#             Search
#            </span>
#            <span class="form-icon">
#             <svg class="icon-search" focusable="false" height="20" width="20">
#              <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-search">
#              </use>
#             </svg>
#            </span>
#            <button class="icon-x__trigger js-formcontrol_clear is-hidden" type="button">
#             <svg class="icon-x icon-x--close" height="20" width="20">
#              <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-x">
#              </use>
#             </svg>
#            </button>
#            <span class="field-validation-valid form__message error text--small" data-valmsg-for="SearchString" data-valmsg-replace="true" id="SearchString-tip" role="tooltip">
#            </span>
#           </div>
#          </div>
#          <button class="search-box__close js-search-box__close" type="button">
#           <svg aria-label="Close" class="icon-x" height="20" width="20">
#            <use xlink:href="/Content/images/sprite--core.svg?v=20230421155022#icon-x">
#            </use>
#           </svg>
#          </button>
#         </div>
#         <div class="search__dropdown js-search__dropdown" data-previewurl="/Navigation/SearchPreviewContent">
#          <div class="loader loader--list-view">
#           <svg class="spinner">
#            <circle class="spinner__circle" cx="20" cy="20" r="18">
#            </circle>
#           </svg>
#          </div>
#          <p class="search__message js-search__message">
#           Please fill in at least 3 characters
#          </p>
#          <div class="search__dropdown-results search__dropdown-results--preview is-loading-element is-loading-element--blur js-search__dropdown-preview">
#          </div>
#          <div class="search__dropdown-results js-search__dropdown-results is-hidden is-loading-element is-loading-element--blur">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="masthead__user">
#       <a class="nav-link masthead__item-link text--bold" href="/user?returnUrl=%2Franking%2Fcategory.aspx%3Fid%3D42511%26category%3D472%26C472FOC%3D%26p%3D1%26ps%3D100">
#        <span class="nav-link__value">
#         Log In
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="masthead masthead--sticky js-masthead--sticky">
#      <div class="masthead__main flex-item--truncate">
#       <label class="nav-toggle__button masthead__item-link menu__button" for="nav-toggle" title="Click to show site navigation">
#        <span class="nav-toggle__title">
#         Menu
#        </span>
#        <span class="hamburger">
#        </span>
#       </label>
#       <div class="hgroup truncate">
#        <a class="to-top" href="#">
#         <h2 class="hgroup__heading truncate">
#          BWF - BWF World Rankings - Overview
#         </h2>
#        </a>
#       </div>
#      </div>
#      <div class="masthead__user">
#       <a class="nav-link masthead__item-link text--bold" href="/user?returnUrl=%2Franking%2Fcategory.aspx%3Fid%3D42511%26category%3D472%26C472FOC%3D%26p%3D1%26ps%3D100">
#        <span class="nav-link__value">
#         Log In
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="wrapper--legacy" id="content">
#      <div class="ad--container" id="topbanner">
#       <div class="ad banner js-ad_async" data-ad-personalized-allowed="1" data-wz="tw_ranking_en_top728x90" data-zs="r70">
#       </div>
#      </div>
#      <div id="organizationmenu">
#       <img class="logo" src="//static.tournamentsoftware.com/content/images/themes/bwf/no-photo.png">
#        <div class="header">
#         <h3>
#          BWF World Rankings
#          <span class="rankingdate">
#           (10/1/2024)
#          </span>
#         </h3>
#         <p class="subtitle">
#          Last updated: Tuesday, October 1, 2024 1:47 AM
#         </p>
#        </div>
#        <ul class="tabs" id="cphPage_cphPage_tmRankingMenu">
#         <li class="active firstactive">
#          <a class="active" href="ranking.aspx?id=42511">
#           Overview
#          </a>
#         </li>
#         <li>
#          <a href="tournaments.aspx?id=42511">
#           Tournaments
#          </a>
#         </li>
#         <li>
#          <a href="find.aspx?id=42511">
#           Search
#          </a>
#         </li>
#        </ul>
#       </img>
#      </div>
#      <p>
#       <strong>
#        Ranking week:
#       </strong>
#       <select class="publication" id="cphPage_cphPage_cphPage_dlPublication" name="ctl00$ctl00$ctl00$cphPage$cphPage$cphPage$dlPublication" onchange="javascript:setTimeout('__doPostBack(\'ctl00$ctl00$ctl00$cphPage$cphPage$cphPage$dlPublication\',\'\')', 0)">
#        <option value="42633">
#         10/8/2024
#        </option>
#        <option selected="selected" value="42511">
#         10/1/2024
#        </option>
#        <option value="42400">
#         9/24/2024
#        </option>
#        <option value="42307">
#         9/17/2024
#        </option>
#        <option value="42196">
#         8/27/2015
#        </option>
#        <option value="9558">
#         8/20/2015
#        </option>
#        <option value="9526">
#         8/13/2015
#        </option>
#        <option value="9494">
#         8/6/2015
#        </option>
#        <option value="9464">
#         7/30/2015
#        </option>
#        <option value="9416">
#         7/23/2015
#        </option>
#        <option value="9372">
#         7/16/2015
#        </option>
#        <option value="9349">
#         7/9/2015
#        </option>
#        <option value="9282">
#         7/2/2015
#        </option>
#        <option value="9266">
#         6/25/2015
#        </option>
#        <option value="9232">
#         6/18/2015
#        </option>
#        <option value="9193">
#         6/11/2015
#        </option>
#        <option value="9162">
#         6/4/2015
#        </option>
#        <option value="9109">
#         5/28/2015
#        </option>
#        <option value="9049">
#         5/21/2015
#        </option>
#        <option value="9038">
#         5/14/2015
#        </option>
#        <option value="8993">
#         5/7/2015
#        </option>
#        <option value="8923">
#         4/30/2015
#        </option>
#        <option value="8884">
#         4/23/2015
#        </option>
#        <option value="8843">
#         4/16/2015
#        </option>
#        <option value="8745">
#         4/9/2015
#        </option>
#        <option value="8705">
#         4/2/2015
#        </option>
#        <option value="8654">
#         3/26/2015
#        </option>
#        <option value="8619">
#         3/19/2015
#        </option>
#        <option value="8576">
#         3/12/2015
#        </option>
#        <option value="8496">
#         3/5/2015
#        </option>
#        <option value="8480">
#         2/26/2015
#        </option>
#        <option value="8440">
#         2/18/2015
#        </option>
#        <option value="8414">
#         2/12/2015
#        </option>
#        <option value="8367">
#         2/5/2015
#        </option>
#        <option value="8324">
#         1/29/2015
#        </option>
#        <option value="8284">
#         1/22/2015
#        </option>
#        <option value="8213">
#         1/15/2015
#        </option>
#        <option value="8173">
#         1/8/2015
#        </option>
#        <option value="8141">
#         1/2/2015
#        </option>
#        <option value="8092">
#         12/24/2014
#        </option>
#        <option value="8070">
#         12/18/2014
#        </option>
#        <option value="8023">
#         12/11/2014
#        </option>
#        <option value="7989">
#         12/4/2014
#        </option>
#        <option value="7947">
#         11/27/2014
#        </option>
#        <option value="7918">
#         11/20/2014
#        </option>
#        <option value="7883">
#         11/13/2014
#        </option>
#        <option value="7845">
#         11/6/2014
#        </option>
#        <option value="7796">
#         10/30/2014
#        </option>
#        <option value="7748">
#         10/23/2014
#        </option>
#        <option value="7689">
#         10/16/2014
#        </option>
#        <option value="7647">
#         10/9/2014
#        </option>
#        <option value="7606">
#         10/2/2014
#        </option>
#        <option value="7567">
#         9/25/2014
#        </option>
#        <option value="7530">
#         9/18/2014
#        </option>
#        <option value="7498">
#         9/11/2014
#        </option>
#        <option value="7461">
#         9/4/2014
#        </option>
#        <option value="7417">
#         8/28/2014
#        </option>
#        <option value="7393">
#         8/21/2014
#        </option>
#        <option value="7366">
#         8/14/2014
#        </option>
#        <option value="7323">
#         8/7/2014
#        </option>
# ...
#        </td>
#        <td class="rank_equal" title="Previous rank: 95">
#        </td>
#        <td>
#        </td>
#        <td>
#         MAS
#        </td>
#        <td>
#         <img alt="Malaysia" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/MAS.svg" title="Malaysia" width="16"/>
#         <span class="printonly flag">
#          [MAS]
#         </span>
#         <a href="player.aspx?id=42511&amp;player=2215619">
#          Sholeh AIDIL
#         </a>
#        </td>
#        <td>
#         <a class="icon profile" href="/player-profile/7DA6A502-73D7-4955-97B8-11060FD7D927" title="Profile">
#         </a>
#        </td>
#        <td>
#         79110
#        </td>
#        <td class="right rankingpoints">
#         19090
#        </td>
#        <td class="right">
#         9
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=0EB2BA3B-3867-465E-8D04-CEDE4A566474">
#          Asia
#         </a>
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=412A5C75-4487-4EBB-BC15-EB63C56A6A3B">
#          Malaysia
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="rank">
#         <div style="">
#          96
#         </div>
#        </td>
#        <td class="rank_equal" title="Previous rank: 96">
#        </td>
#        <td>
#        </td>
#        <td>
#         IND
#        </td>
#        <td>
#         <img alt="India" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/IND.svg" title="India" width="16"/>
#         <span class="printonly flag">
#          [IND]
#         </span>
#         <a href="player.aspx?id=42511&amp;player=2131992">
#          Raghu MARISWAMY
#         </a>
#        </td>
#        <td>
#         <a class="icon profile" href="/player-profile/8EAE272D-DC7A-4AF9-8D46-96B3E9B68D26" title="Profile">
#         </a>
#        </td>
#        <td>
#         62932
#        </td>
#        <td class="right rankingpoints">
#         19070
#        </td>
#        <td class="right">
#         18
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=0EB2BA3B-3867-465E-8D04-CEDE4A566474">
#          Asia
#         </a>
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=1FE14BDB-553D-4E5F-80BC-7401F484B14A">
#          India
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="rank">
#         <div style="">
#          97
#         </div>
#        </td>
#        <td class="rank_equal" title="Previous rank: 97">
#        </td>
#        <td>
#        </td>
#        <td>
#         PER
#        </td>
#        <td>
#         <img alt="Peru" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/PER.svg" title="Peru" width="16"/>
#         <span class="printonly flag">
#          [PER]
#         </span>
#         <a href="player.aspx?id=42511&amp;player=2966417">
#          Adriano VIALE
#         </a>
#        </td>
#        <td>
#         <a class="icon profile" href="/player-profile/A85821A0-CC3E-4673-9053-67CE0F9A4397" title="Profile">
#         </a>
#        </td>
#        <td>
#         55942
#        </td>
#        <td class="right rankingpoints">
#         19018
#        </td>
#        <td class="right">
#         15
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=A9296973-FB35-4724-883F-78BFFCE7934A">
#          Pan America
#         </a>
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=2FC49674-10FF-4D51-8378-F49AD3F58B24">
#          Peru
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="rank">
#         <div style="">
#          98
#         </div>
#        </td>
#        <td class="rank_equal" title="Previous rank: 98">
#        </td>
#        <td>
#        </td>
#        <td>
#         GER
#        </td>
#        <td>
#         <img alt="Germany" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/GER.svg" title="Germany" width="16"/>
#         <span class="printonly flag">
#          [GER]
#         </span>
#         <a href="player.aspx?id=42511&amp;player=146260">
#          Kai SCHAEFER
#         </a>
#        </td>
#        <td>
#         <a class="icon profile" href="/player-profile/F765CDBC-E01B-4F87-92F5-2E4E05FBF128" title="Profile">
#         </a>
#        </td>
#        <td>
#         20808
#        </td>
#        <td class="right rankingpoints">
#         18741
#        </td>
#        <td class="right">
#         19
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">
#          Europe
#         </a>
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=405269D5-E629-4546-83D5-834F818F8584">
#          Germany
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="rank">
#         <div style="">
#          99
#         </div>
#        </td>
#        <td class="rank_equal" title="Previous rank: 99">
#        </td>
#        <td>
#        </td>
#        <td>
#         FRA
#        </td>
#        <td>
#         <img alt="France" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/FRA.svg" title="France" width="16"/>
#         <span class="printonly flag">
#          [FRA]
#         </span>
#         <a href="player.aspx?id=42511&amp;player=2875558">
#          Enogat ROY
#         </a>
#        </td>
#        <td>
#         <a class="icon profile" href="/player-profile/9F87B1B8-F6CE-4814-B370-79E164E23330" title="Profile">
#         </a>
#        </td>
#        <td>
#         85118
#        </td>
#        <td class="right rankingpoints">
#         18630
#        </td>
#        <td class="right">
#         16
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">
#          Europe
#         </a>
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=0F8E17C1-FC1A-4584-A61E-40A81EFD2F11">
#          France
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="rank">
#         <div style="">
#          100
#         </div>
#        </td>
#        <td class="rank_equal" title="Previous rank: 100">
#        </td>
#        <td>
#        </td>
#        <td>
#         SUI
#        </td>
#        <td>
#         <img alt="Switzerland" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/SUI.svg" title="Switzerland" width="16"/>
#         <span class="printonly flag">
#          [SUI]
#         </span>
#         <a href="player.aspx?id=42511&amp;player=946347">
#          Tobias KUENZI
#         </a>
#        </td>
#        <td>
#         <a class="icon profile" href="/player-profile/94ECC19D-4C42-486C-BDA4-860A2B58E21C" title="Profile">
#         </a>
#        </td>
#        <td>
#         60427
#        </td>
#        <td class="right rankingpoints">
#         18238
#        </td>
#        <td class="right">
#         17
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">
#          Europe
#         </a>
#        </td>
#        <td>
#         <a href="category.aspx?id=42511&amp;category=472&amp;ogid=DC7110A9-01B7-47DF-B26B-1213CF4030BD">
#          Switzerland
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="noruler" colspan="11">
#         <div class="pagenumbers">
#          <span class="page_caption">
#           Page 1 of 19 - 1881 results
#          </span>
#          <span class="pagenrs">
#           <span class="page_selected">
#            1
#           </span>
#           <span class="pipe">
#            |
#           </span>
#           <a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=2&amp;ps=100">
#            2
#           </a>
#           <span class="pipe">
#            |
#           </span>
#           <a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=3&amp;ps=100">
#            3
#           </a>
#           <span class="pipe">
#            |
#           </span>
#           <a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=4&amp;ps=100">
#            4
#           </a>
#           <span class="pipe">
#            |
#           </span>
#           <a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=5&amp;ps=100">
#            5
#           </a>
#           <span class="pipe">
#            |
#           </span>
#           <a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=6&amp;ps=100">
#            6
#           </a>
#           <span class="pipe">
#            |
#           </span>
#           <a class="page_next" href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=2&amp;ps=100" title="Next">
#            Next
#           </a>
#           <a class="page_ffw" href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=9&amp;ps=100" title="Go to page 9">
#            Go to page 9
#           </a>
#           <a class="page_last" href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=19&amp;ps=100" title="Last">
#            Last
#           </a>
#          </span>
#          <span class="pagesize">
#           Results per page
#           <select id="_pagesize" name="_pagesize" onchange="window.location.href=('/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=1&amp;ps=pagesize').replace('pagesize',this.options[this.selectedIndex].value)">
#            <option value="10">
#             10
#            </option>
#            <option value="25">
#             25
#            </option>
#            <option value="50">
#             50
#            </option>
#            <option selected="selected" value="100">
#             100
#            </option>
#           </select>
#          </span>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <!-- footer -->
#     <footer class="wrapper wrapper--hightlight-dark page-foot" role="contentinfo">
#      <div class="wrapper--padding">
#       <div class="row">
#        <div class="col-sm-4 col-xs-12 footer__column">
#         <h6 class="page-foot__title">
#          Account
#         </h6>
#         <ul class="list list--naked">
#          <li class="list__item">
#           <a class="nav-link text--link-white" href="/user/Signup?ReturnUrl=%2Franking%2Fcategory.aspx%3Fid%3D42511%26category%3D472%26C472FOC%3D%26p%3D1%26ps%3D100">
#            <span class="nav-link__value">
#             Sign up
#            </span>
#           </a>
#          </li>
#          <li class="list__item">
#           <a class="nav-link text--link-white" href="/user?ReturnUrl=%2Franking%2Fcategory.aspx%3Fid%3D42511%26category%3D472%26C472FOC%3D%26p%3D1%26ps%3D100">
#            <span class="nav-link__value">
#             Log in
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-sm-4 col-xs-6 footer__column">
#         <h6 class="page-foot__title">
#          Contact
#         </h6>
#         <ul class="list--naked list">
#          <li class="list__item">
#           <span class="nav-link">
#            <span class="nav-link__value">
#             <span class="p-adr">
#              <span class="p-name">
#               BWF HQ
#              </span>
#              <span class="p-street-adress">
#               Unit No. 1, Level 29
#               <br/>
#               Naza Tower
#               <br/>
#               No 10 Persiaran KLCC
#              </span>
#              <span class="p-postal-code">
#               50088 Kuala Lumpur
#              </span>
#              <span class="p-country-name">
#               Malaysia
#              </span>
#             </span>
#            </span>
#           </span>
#          </li>
#          <li class="list__item">
#           <a class="nav-link p-tel text--link-white" href="tel:+60326319188" rel="nofollow">
#            <svg aria-hidden="true" class="icon" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <use xlink:href="/Content/icons/phone.svg?v=20241003101011#icon">
#             </use>
#            </svg>
#            <span class="nav-link__value">
#             +603 2631 9188
#            </span>
#           </a>
#          </li>
#          <li class="list__item">
#           <a class="nav-link p-email text--link-white" href="mailto:bwf@bwfbadminton.org" rel="nofollow">
#            <svg aria-hidden="true" class="icon" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <use xlink:href="/Content/icons/envelope.svg?v=20241003101011#icon">
#             </use>
#            </svg>
#            <span class="nav-link__value">
#             bwf@bwfbadminton.org
#            </span>
#           </a>
#          </li>
#          <li class="list__item">
#           <a class="nav-link btn--small btn--secondary btn margin-top--small" href="/Support/HelpCenter">
#            <span class="nav-link__value">
#             Help Center
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-sm-4 col-xs-6 footer__column">
#         <h6 class="page-foot__title">
#          Social media
#         </h6>
#         <ul class="list--inline list">
#          <li class="list__item">
#           <a class="nav-link social-media__link" href="https://twitter.com/bwfmedia" rel="noopener" target="_blank">
#            <span class="nav-link__value">
#             <svg aria-hidden="true" class="icon icon-twitter social-media__icon" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#              <use xlink:href="/Content/icons/twitter.svg?v=20241003101011#icon">
#              </use>
#             </svg>
#            </span>
#           </a>
#          </li>
#          <li class="list__item">
#           <a class="nav-link social-media__link" href="https://www.facebook.com/bwfbadminton" rel="noopener" target="_blank">
#            <span class="nav-link__value">
#             <svg aria-hidden="true" class="icon icon-facebook social-media__icon" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#              <use xlink:href="/Content/icons/facebook.svg?v=20241003101011#icon">
#              </use>
#             </svg>
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="footer__sub--sub">
#        <a class="nav-link margin-top" href="https://www.tournamentsoftware.com" rel="noopener" target="_blank">
#         <span class="nav-link__value">
#          <img alt="Tournament software" class="footer-page__img" src="/Content/images/providedby--mono.svg?v=20230421154817"/>
#         </span>
#        </a>
#       </div>
#       <ul class="list list--inline list--bordered margin-top">
#        <li class="list__item">
#         <a class="nav-link text--link-white text--link-white-muted" href="/Home">
#          <span class="nav-link__value">
#           Home
#          </span>
#         </a>
#        </li>
#        <li class="list__item">
#         <a class="nav-link text--link-white text--link-white-muted" href="/features">
#          <span class="nav-link__value">
#           See what's new
#          </span>
#         </a>
#        </li>
#        <li class="list__item">
#         <a class="nav-link text--link-white text--link-white-muted" href="/cookiewall?ReturnUrl=%2Franking%2Fcategory.aspx%3Fid%3D42511%26category%3D472%26C472FOC%3D%26p%3D1%26ps%3D100">
#          <span class="nav-link__value">
#           Cookies
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </footer>
#     <!-- // footer -->
#    </div>
#    <div class="backdrop js-main-search-backdrop">
#    </div>
#    <script type="text/javascript">
#     //<![CDATA[
# svg4everybody();
#
# AddEvent(window,'load',SetTableRulerEvents);$(document).ready(function() { $('.rankingfilter select, select.publication').not('.chosen').chosen({disable_search:true});
#  $('.chosen').chosen({search_contains:true});
#  }); $('.chzn-select-deselect').chosen({allow_single_deselect:true});
# $(document).ready(function() { bindBanners(); });
# //]]>
#    </script>
#   </form>
#  </body>
# </html>

# %%
ranking_table = soup.find('table', class_='ruler') # Find the table containing players data
print(ranking_table)
# Out:
# <table class="ruler" style="min-width:762px">
# <caption>
# 		Men's Singles
# 	</caption><tr>
# </tr><tr>
# <th class="orderby rank" colspan="2"><a class="down" href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=1&amp;desc=1">Rank</a></th><th class="orderby"> </th><th class="orderby left"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=10">Country</a></th><th class="orderby left"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=10">Player</a></th><th class="orderby left"> </th><th class="orderby">Member ID</th><th class="orderby right rankingpoints"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=2">Points</a></th><th class="orderby right"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=7">Tournaments</a></th><th class="orderby"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=13">Confederation</a></th><th class="orderby"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=12">Country</a></th>
# </tr><tr>
# <td class="rank"><div style="">1</div></td><td class="rank_equal" title="Previous rank: 1"> </td><td> </td><td>CHN</td><td><img alt="China" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/CHN.svg" title="China" width="16"><span class="printonly flag">[CHN] </span><a href="player.aspx?id=42511&amp;player=990139">SHI Yu Qi</a></img></td><td><a class="icon profile" href="/player-profile/38CBD70E-A643-4170-9E6A-28863412DC7B" title="Profile"></a></td><td>57945</td><td class="right rankingpoints">101815</td><td class="right">18</td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=0EB2BA3B-3867-465E-8D04-CEDE4A566474">Asia</a></td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=AAAFC650-A51F-42D1-AD4C-E0F53569D04B">China</a></td>
# </tr><tr>
# <td class="rank"><div style="">2</div></td><td class="rank_equal" title="Previous rank: 2"> </td><td> </td><td>DEN</td><td><img alt="Denmark" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/DEN.svg" title="Denmark" width="16"/><span class="printonly flag">[DEN] </span><a href="player.aspx?id=42511&amp;player=147387">Viktor AXELSEN</a></td><td><a class="icon profile" href="/player-profile/3BF0C3EA-7BFB-4CC9-A955-3712D850CFA4" title="Profile"></a></td><td>25831</td><td class="right rankingpoints">93790</td><td class="right">14</td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">Europe</a></td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=58BCE2D9-0DC7-4FDA-8205-A508ABCF0841">Denmark</a></td>
# </tr><tr>
# <td class="rank"><div style="">3</div></td><td class="rank_equal" title="Previous rank: 3"> </td><td> </td><td>DEN</td><td><img alt="Denmark" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/DEN.svg" title="Denmark" width="16"/><span class="printonly flag">[DEN] </span><a href="player.aspx?id=42511&amp;player=396249">Anders ANTONSEN</a></td><td><a class="icon profile" href="/player-profile/473960FD-334B-476F-9821-8ED9398BC1A8" title="Profile"></a></td><td>91554</td><td class="right rankingpoints">84241</td><td class="right">22</td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">Europe</a></td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid
class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/GER.svg" title="Germany" width="16"/><span class="printonly flag">[GER] </span><a href="player.aspx?id=42511&amp;player=146260">Kai SCHAEFER</a></td><td><a class="icon profile" href="/player-profile/F765CDBC-E01B-4F87-92F5-2E4E05FBF128" title="Profile"></a></td><td>20808</td><td class="right rankingpoints">18741</td><td class="right">19</td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">Europe</a></td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=405269D5-E629-4546-83D5-834F818F8584">Germany</a></td>
# </tr><tr>
# <td class="rank"><div style="">99</div></td><td class="rank_equal" title="Previous rank: 99"> </td><td> </td><td>FRA</td><td><img alt="France" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/FRA.svg" title="France" width="16"/><span class="printonly flag">[FRA] </span><a href="player.aspx?id=42511&amp;player=2875558">Enogat ROY</a></td><td><a class="icon profile" href="/player-profile/9F87B1B8-F6CE-4814-B370-79E164E23330" title="Profile"></a></td><td>85118</td><td class="right rankingpoints">18630</td><td class="right">16</td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">Europe</a></td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=0F8E17C1-FC1A-4584-A61E-40A81EFD2F11">France</a></td>
# </tr><tr>
# <td class="rank"><div style="">100</div></td><td class="rank_equal" title="Previous rank: 100"> </td><td> </td><td>SUI</td><td><img alt="Switzerland" class="intext flag" height="14" src="//static.tournamentsoftware.com/content/images/flags/SUI.svg" title="Switzerland" width="16"/><span class="printonly flag">[SUI] </span><a href="player.aspx?id=42511&amp;player=946347">Tobias KUENZI</a></td><td><a class="icon profile" href="/player-profile/94ECC19D-4C42-486C-BDA4-860A2B58E21C" title="Profile"></a></td><td>60427</td><td class="right rankingpoints">18238</td><td class="right">17</td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=DF30371B-9D1A-4322-AF0F-182B40D3C4F4">Europe</a></td><td><a href="category.aspx?id=42511&amp;category=472&amp;ogid=DC7110A9-01B7-47DF-B26B-1213CF4030BD">Switzerland</a></td>
# </tr><tr>
# <td class="noruler" colspan="11"><div class="pagenumbers"><span class="page_caption">Page 1 of 19 - 1881 results</span><span class="pagenrs"><span class="page_selected">1</span><span class="pipe">|</span><a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=2&amp;ps=100">2</a><span class="pipe">|</span><a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=3&amp;ps=100">3</a><span class="pipe">|</span><a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=4&amp;ps=100">4</a><span class="pipe">|</span><a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=5&amp;ps=100">5</a><span class="pipe">|</span><a href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=6&amp;ps=100">6</a><span class="pipe">|</span><a class="page_next" href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=2&amp;ps=100" title="Next">Next</a><a class="page_ffw" href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=9&amp;ps=100" title="Go to page 9">Go to page 9</a><a class="page_last" href="/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=19&amp;ps=100" title="Last">Last</a></span><span class="pagesize">Results per page<select id="_pagesize" name="_pagesize" onchange="window.location.href=('/ranking/category.aspx?id=42511&amp;category=472&amp;C472FOC=&amp;p=1&amp;ps=pagesize').replace('pagesize',this.options[this.selectedIndex].value)"><option value="10">10</option><option value="25">25</option><option value="50">50</option><option selected="selected" value="100">100</option></select></span></div></td>
# </tr>
# </table>

# %%
table_columns = ranking_table.find_all('th') # Find the all table columns which are under 'th' tag
table_columns
# Out:
# [<th class="orderby rank" colspan="2"><a class="down" href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=1&amp;desc=1">Rank</a></th>,
#  <th class="orderby"> </th>,
#  <th class="orderby left"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=10">Country</a></th>,
#  <th class="orderby left"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=10">Player</a></th>,
#  <th class="orderby left"> </th>,
#  <th class="orderby">Member ID</th>,
#  <th class="orderby right rankingpoints"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=2">Points</a></th>,
#  <th class="orderby right"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=7">Tournaments</a></th>,
#  <th class="orderby"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=13">Confederation</a></th>,
#  <th class="orderby"><a href="?id=42511&amp;category=472&amp;ps=100&amp;C472FOC=&amp;order=12">Country</a></th>]

# %%
# This filters out empty strings: table_columns = [title for title in table_titles if title] (Don't need this in this project)
columns = [column.text.strip() for column in table_columns] # Convert all columns into a list for a DataFrame creation later
print(columns)
# Out:
# ['Rank', '', 'Country', 'Player', '', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
row_data = ranking_table.find_all('tr') # Find all values in each row which are under the 'td' tag
#row_test = [row.text.strip() for row in row_data[2]] 
#print(row_test)
individual_row_data = [data.text.strip() for data in row_data] # Convert all values into list
individual_row_data[2]
#individual_row_data # Check if the amount of values in each row matches the table column which is 10 from the list above
# Out:
# '1\xa0\xa0CHN[CHN] SHI Yu Qi5794510181518AsiaChina'

# %%
# Turns out there are 11 values in each row. To match these data correctly with our table columns, we need to add another column in the table with the correct position.
columns.insert(1, 'x1') # Add a column called 'x1'. Don't worry about the vague name since it will store no data then we will drop it later with other unnecessary columns 
columns[2] = 'x2' # Rename the empty column as 'x2' which will be dropped later.
columns[3] = 'Country Code' # Rename to differentiate with the Country column.
columns[5] = 'x3' # Rename the empty column as 'x3' which will be dropped later.
print(columns)
# Out:
# ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
df = pd.DataFrame(columns = columns) # Create DataFrame
df
# Out:
# Empty DataFrame
# Columns: [Rank, x1, x2, Country Code, Player, x3, Member ID, Points, Tournaments, Confederation, Country]
# Index: []

# %%
all_rows = ranking_table.find_all('tr') # Find all rows on the page which are under the 'tr' tag
test_row = [row.text.strip() for row in all_rows[2]] # Convert all columns into a list for a DataFrame creation later
print(test_row)
# Out:
# ['', '1', '', '', 'CHN', '[CHN] SHI Yu Qi', '', '57945', '101815', '18', 'Asia', 'China', '']

# %%
for row in all_rows[2:102]: # Create a loop to get all row data and add it into the DataFrame df. Range from 2:102 to get rid of the headers & footers not being part of the data we need, and to avoid error of mismatched columns.
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = individual_row_data
df
# Out:
#    Rank x1 x2 Country Code                 Player x3 Member ID  Points  \
# 0     1                CHN        [CHN] SHI Yu Qi        57945  101815
# 1     2                DEN   [DEN] Viktor AXELSEN        25831   93790
# 2     3                DEN  [DEN] Anders ANTONSEN        91554   84241
# 3     4                JPN    [JPN] Kodai NARAOKA        62063   84197
# 4     5                MAS      [MAS] LEE Zii Jia        81561   83716
# ..  ... .. ..          ...                    ... ..       ...     ...
# 95   96                IND  [IND] Raghu MARISWAMY        62932   19070
# 96   97                PER    [PER] Adriano VIALE        55942   19018
# 97   98                GER     [GER] Kai SCHAEFER        20808   18741
# 98   99                FRA       [FRA] Enogat ROY        85118   18630
# 99  100                SUI    [SUI] Tobias KUENZI        60427   18238
#
#    Tournaments Confederation      Country
# 0           18          Asia        China
# 1           14        Europe      Denmark
# 2           22        Europe      Denmark
# 3           22          Asia        Japan
# 4           22          Asia     Malaysia
# ..         ...           ...          ...
# 95          18          Asia        India
# 96          15   Pan America         Peru
# 97          19        Europe      Germany
# 98          16        Europe       France
# 99          17        Europe  Switzerland
#
# [100 rows x 11 columns]

# %%
# Dropping the columns 'x1', 'x2', 'x3'
df = df.drop(columns=['x1', 'x2', 'x3'])
df
# Out:
#    Rank Country Code                 Player Member ID  Points Tournaments  \
# 0     1          CHN        [CHN] SHI Yu Qi     57945  101815          18
# 1     2          DEN   [DEN] Viktor AXELSEN     25831   93790          14
# 2     3          DEN  [DEN] Anders ANTONSEN     91554   84241          22
# 3     4          JPN    [JPN] Kodai NARAOKA     62063   84197          22
# 4     5          MAS      [MAS] LEE Zii Jia     81561   83716          22
# ..  ...          ...                    ...       ...     ...         ...
# 95   96          IND  [IND] Raghu MARISWAMY     62932   19070          18
# 96   97          PER    [PER] Adriano VIALE     55942   19018          15
# 97   98          GER     [GER] Kai SCHAEFER     20808   18741          19
# 98   99          FRA       [FRA] Enogat ROY     85118   18630          16
# 99  100          SUI    [SUI] Tobias KUENZI     60427   18238          17
#
#    Confederation      Country
# 0           Asia        China
# 1         Europe      Denmark
# 2         Europe      Denmark
# 3           Asia        Japan
# 4           Asia     Malaysia
# ..           ...          ...
# 95          Asia        India
# 96   Pan America         Peru
# 97        Europe      Germany
# 98        Europe       France
# 99        Europe  Switzerland
#
# [100 rows x 8 columns]

# %%
# Export the result as csv file
# df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\Player.csv', index = False)

# %% [markdown]
# ### **Men's Singles**

# %%
# Men's Singles URL, filtered by 100 results on each page.
ms_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this info to work with the last page which doesn't contain 100 results as the previous ones.
ms_page_number = 19
ms_results = 1831

# %%
# From the Test above, now we know all the columns needed for the DataFrame. Create a list of column names.
list = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
# Create DataFrame
ms_df = pd.DataFrame(columns = list)
ms_df
# Out:
# Empty DataFrame
# Columns: [Rank, x1, x2, Country Code, Player, x3, Member ID, Points, Tournaments, Confederation, Country]
# Index: []

# %%
# Create a loop to add data to all pages in DataFrame 
# Loop through pages 1 to 19
for ms_page in range(1, ms_page_number +1):
    if ms_page < ms_page_number: # From pages 1-18 with 100 results on each page
        # Format the URL with the current page number
        ms_url = ms_base_url.format(ms_page)
        # Make a request to the URL
        ms_response = requests.get(ms_url, headers=headers)
        ms_soup = BeautifulSoup(ms_response.text, 'html.parser')
        ms_ranking_table = ms_soup.find('table', class_='ruler')
        ms_all_rows = ms_ranking_table.find_all('tr')[2:102]
        for ms_row in ms_all_rows:
            ms_row_data = ms_row.find_all('td')
            ms_individual_row_data = [ms_data.text.strip() for ms_data in ms_row_data]
            ms_length = len(ms_df)
            if ms_length < ms_results:
                ms_df.loc[ms_length] = ms_individual_row_data
            else:
                break
            
    else: # Page 19 with less than 100 results on this page
        # Format the URL with the current page number
        ms_url = ms_base_url.format(ms_page)
        # Make a request to the URL
        ms_response = requests.get(ms_url, headers=headers)
        ms_soup = BeautifulSoup(ms_response.text, 'html.parser')
        ms_ranking_table = ms_soup.find('table', class_='ruler')
        ms_all_rows = ms_ranking_table.find_all('tr')[2:(ms_results-((ms_page_number-1)*100) +2)]
        for ms_row in ms_all_rows:
            ms_row_data = ms_row.find_all('td')
            ms_individual_row_data = [ms_data.text.strip() for ms_data in ms_row_data]
            ms_length = len(ms_df)
            if ms_length < ms_results:
                ms_df.loc[ms_length] = ms_individual_row_data
            else:
                break

ms_df
# Out:
#       Rank x1 x2 Country Code                        Player x3 Member ID  \
# 0        1                CHN               [CHN] SHI Yu Qi        57945
# 1        2                DEN          [DEN] Viktor AXELSEN        25831
# 2        3                DEN         [DEN] Anders ANTONSEN        91554
# 3        4                JPN           [JPN] Kodai NARAOKA        62063
# 4        5                MAS             [MAS] LEE Zii Jia        81561
# ...    ... .. ..          ...                           ... ..       ...
# 1826  1767                UGA    [UGA] Hassan Jamil MAKINDA        33916
# 1827  1767                UGA             [UGA] Latif NGOBI        29626
# 1828  1767                UGA           [UGA] Abaasi BBAALE        89938
# 1829  1767                UGA  [UGA] Preet Nikulkumar PATEL        34706
# 1830  1767                UGA          [UGA] Arafat KALOOBE        22032
#
#       Points Tournaments Confederation   Country
# 0     101815          18          Asia     China
# 1      93790          14        Europe   Denmark
# 2      84241          22        Europe   Denmark
# 3      84197          22          Asia     Japan
# 4      83716          22          Asia  Malaysia
# ...      ...         ...           ...       ...
# 1826      20           1        Africa    Uganda
# 1827      20           1        Africa    Uganda
# 1828      20           1        Africa    Uganda
# 1829      20           1        Africa    Uganda
# 1830      20           1        Africa    Uganda
#
# [1831 rows x 11 columns]

# %%
# Dropping the columns 'x1', 'x2', 'x3'
ms_df = ms_df.drop(columns=['x1', 'x2', 'x3'])

# %%
# Add 'Category' column
ms_df['Category'] = 'MS'

# %%
ms_df
# Out:
#       Rank Country Code                        Player Member ID  Points  \
# 0        1          CHN               [CHN] SHI Yu Qi     57945  101815
# 1        2          DEN          [DEN] Viktor AXELSEN     25831   93790
# 2        3          DEN         [DEN] Anders ANTONSEN     91554   84241
# 3        4          JPN           [JPN] Kodai NARAOKA     62063   84197
# 4        5          MAS             [MAS] LEE Zii Jia     81561   83716
# ...    ...          ...                           ...       ...     ...
# 1826  1767          UGA    [UGA] Hassan Jamil MAKINDA     33916      20
# 1827  1767          UGA             [UGA] Latif NGOBI     29626      20
# 1828  1767          UGA           [UGA] Abaasi BBAALE     89938      20
# 1829  1767          UGA  [UGA] Preet Nikulkumar PATEL     34706      20
# 1830  1767          UGA          [UGA] Arafat KALOOBE     22032      20
#
#      Tournaments Confederation   Country Category
# 0             18          Asia     China       MS
# 1             14        Europe   Denmark       MS
# 2             22        Europe   Denmark       MS
# 3             22          Asia     Japan       MS
# 4             22          Asia  Malaysia       MS
# ...          ...           ...       ...      ...
# 1826           1        Africa    Uganda       MS
# 1827           1        Africa    Uganda       MS
# 1828           1        Africa    Uganda       MS
# 1829           1        Africa    Uganda       MS
# 1830           1        Africa    Uganda       MS
#
# [1831 rows x 9 columns]

# %%
#ms_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\MS Player.csv', index = False)

# %% [markdown]
# ### **Women's Singles**

# %%
# Women's Singles URL, filtered by 100 results on each page.
ws_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42633&category=473&C473FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
# After checking with the filter by 100 results on each page.
# We need this info to work with the last page which doesn't contain 100 results as the previous ones.
ws_page_number = 13
ws_results = 1224

# %%
# From the Test above, now we know all the columns needed for the DataFrame. Create a list of column names.
list = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
# Create DataFrame
ws_df = pd.DataFrame(columns = list)
ws_df
# Out:
# Empty DataFrame
# Columns: [Rank, x1, x2, Country Code, Player, x3, Member ID, Points, Tournaments, Confederation, Country]
# Index: []

# %%
# Create a loop to add data to all pages in DataFrame 
# Loop through pages 1 to 19
for ws_page in range(1, ws_page_number +1):
    if ws_page < ws_page_number: # From pages 1-18 with 100 results on each page
        # Format the URL with the current page number
        ws_url = ws_base_url.format(ws_page)
        # Make a request to the URL
        ws_response = requests.get(ws_url, headers=headers)
        ws_soup = BeautifulSoup(ws_response.text, 'html.parser')
        ws_ranking_table = ws_soup.find('table', class_='ruler')
        ws_all_rows = ws_ranking_table.find_all('tr')[2:102]
        for ws_row in ws_all_rows:
            ws_row_data = ws_row.find_all('td')
            ws_individual_row_data = [ws_data.text.strip() for ws_data in ws_row_data]
            ws_length = len(ws_df)
            if ws_length < ws_results:
                ws_df.loc[ws_length] = ws_individual_row_data
            else:
                break
            
    else: # Page 19 with less than 100 results on this page
        # Format the URL with the current page number
        ws_url = ws_base_url.format(ws_page)
        # Make a request to the URL
        ws_response = requests.get(ws_url, headers=headers)
        ws_soup = BeautifulSoup(ws_response.text, 'html.parser')
        ws_ranking_table = ws_soup.find('table', class_='ruler')
        ws_all_rows = ws_ranking_table.find_all('tr')[2:(ws_results-((ws_page_number-1)*100) +2)]
        for ws_row in ws_all_rows:
            ws_row_data = ws_row.find_all('td')
            ws_individual_row_data = [ws_data.text.strip() for ws_data in ws_row_data]
            ws_length = len(ws_df)
            if ws_length < ws_results:
                ws_df.loc[ws_length] = ws_individual_row_data
            else:
                break

ws_df
# Out:
#       Rank x1 x2 Country Code                    Player x3 Member ID  Points  \
# 0        1     2          CHN         [CHN] CHEN Yu Fei        78778  101682
# 1        2                KOR         [KOR] AN Se Young        87442  100337
# 2        3                CHN         [CHN] WANG Zhi Yi        61854   90895
# 3        4                ESP      [ESP] Carolina MARIN        18228   87736
# 4        5                TPE        [TPE] TAI Tzu Ying        61427   87111
# ...    ... .. ..          ...                       ... ..       ...     ...
# 1219  1194                DEN  [DEN] Mathilde SLOTSAGER        76549      20
# 1220  1194                EST    [EST] Karolina PINTŠUK        87914      20
# 1221  1194                FRA     [FRA] Manon HEITZMANN        99557      20
# 1222  1194                DEN        [DEN] Julie BRINCH        98323      20
# 1223  1194                MLT       [MLT] Martina CLARK        68347      20
#
#      Tournaments Confederation         Country
# 0             14          Asia           China
# 1             12          Asia           Korea
# 2             19          Asia           China
# 3             14        Europe           Spain
# 4             17          Asia  Chinese Taipei
# ...          ...           ...             ...
# 1219           1        Europe         Denmark
# 1220           1        Europe         Estonia
# 1221           1        Europe          France
# 1222           1        Europe         Denmark
# 1223           1        Europe           Malta
#
# [1224 rows x 11 columns]

# %%
# Dropping the columns 'x1', 'x2', 'x3'
ws_df = ws_df.drop(columns=['x1', 'x2', 'x3'])

# %%
# Add 'Category' column
ws_df['Category'] = 'WS'

# %%
ws_df
# Out:
#       Rank Country Code                    Player Member ID  Points  \
# 0        1          CHN         [CHN] CHEN Yu Fei     78778  101682
# 1        2          KOR         [KOR] AN Se Young     87442  100337
# 2        3          CHN         [CHN] WANG Zhi Yi     61854   90895
# 3        4          ESP      [ESP] Carolina MARIN     18228   87736
# 4        5          TPE        [TPE] TAI Tzu Ying     61427   87111
# ...    ...          ...                       ...       ...     ...
# 1219  1194          DEN  [DEN] Mathilde SLOTSAGER     76549      20
# 1220  1194          EST    [EST] Karolina PINTŠUK     87914      20
# 1221  1194          FRA     [FRA] Manon HEITZMANN     99557      20
# 1222  1194          DEN        [DEN] Julie BRINCH     98323      20
# 1223  1194          MLT       [MLT] Martina CLARK     68347      20
#
#      Tournaments Confederation         Country Category
# 0             14          Asia           China       WS
# 1             12          Asia           Korea       WS
# 2             19          Asia           China       WS
# 3             14        Europe           Spain       WS
# 4             17          Asia  Chinese Taipei       WS
# ...          ...           ...             ...      ...
# 1219           1        Europe         Denmark       WS
# 1220           1        Europe         Estonia       WS
# 1221           1        Europe          France       WS
# 1222           1        Europe         Denmark       WS
# 1223           1        Europe           Malta       WS
#
# [1224 rows x 9 columns]

# %%
#ws_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\WS Player.csv', index = False)

# %% [markdown]
# ### **Men's Doubles**

# %%
# Men's Doubles URL, filtered by 100 results on each page.
md_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42633&category=474&C474FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
# After checking with the filter by 100 results on each page.
# We need this info to work with the last page which doesn't contain 100 results as the previous ones.
md_page_number = 15
md_results = 1429

# %%
# From the Test above, now we know all the columns needed for the DataFrame. Create a list of column names.
list = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
# Create DataFrame
md_df = pd.DataFrame(columns = list)
md_df
# Out:
# Empty DataFrame
# Columns: [Rank, x1, x2, Country Code, Player, x3, Member ID, Points, Tournaments, Confederation, Country]
# Index: []

# %%
# Create a loop to add data to all pages in DataFrame 
# Loop through pages 1 to 19
for md_page in range(1, md_page_number +1):
    if md_page < md_page_number: # From pages 1-18 with 100 results on each page
        # Format the URL with the current page number
        md_url = md_base_url.format(md_page)
        # Make a request to the URL
        md_response = requests.get(md_url, headers=headers)
        md_soup = BeautifulSoup(md_response.text, 'html.parser')
        md_ranking_table = md_soup.find('table', class_='ruler')
        md_all_rows = md_ranking_table.find_all('tr')[2:102]
        for md_row in md_all_rows:
            md_row_data = md_row.find_all('td')
            md_individual_row_data = [md_data.text.strip() for md_data in md_row_data]
            md_length = len(md_df)
            if md_length < md_results:
                md_df.loc[md_length] = md_individual_row_data
            else:
                break
            
    else: # Page 19 with less than 100 results on this page
        # Format the URL with the current page number
        md_url = md_base_url.format(md_page)
        # Make a request to the URL
        md_response = requests.get(md_url, headers=headers)
        md_soup = BeautifulSoup(md_response.text, 'html.parser')
        md_ranking_table = md_soup.find('table', class_='ruler')
        md_all_rows = md_ranking_table.find_all('tr')[2:(md_results-((md_page_number-1)*100) +2)]
        for md_row in md_all_rows:
            md_row_data = md_row.find_all('td')
            md_individual_row_data = [md_data.text.strip() for md_data in md_row_data]
            md_length = len(md_df)
            if md_length < md_results:
                md_df.loc[md_length] = md_individual_row_data
            else:
                break

md_df
# Out:
#       Rank x1 x2 Country Code                                          Player  \
# 0        1             CHNCHN            [CHN] LIANG Wei Keng[CHN] WANG Chang
# 1        2             DENDEN  [DEN] Kim ASTRUP[DEN] Anders Skaarup RASMUSSEN
# 2        3             KORKOR          [KOR] KANG Min Hyuk[KOR] SEO Seung Jae
# 3        4             MASMAS              [MAS] Aaron CHIA[MAS] SOH Wooi Yik
# 4        5             CHNCHN              [CHN] HE Ji Ting[CHN] REN Xiang Yu
# ...    ... .. ..          ...                                             ...
# 1424  1415             ESPESP       [ESP] Fernando CIVICO[ESP] Ricardo RETTIG
# 1425  1426             BELBEL         [BEL] Elias BRACKE[BEL] Senne HOUTHOOFD
# 1426  1427             BELBEL         [BEL] Charles FOUYN[BEL] Baptiste ROLIN
# 1427  1427             FIJFIJ               [FIJ] Jared CHUNG[FIJ] Robert LOO
# 1428  1427             COKCOK          [COK] Brendan LEE[COK] Emanuela MATAIO
#
#      x3   Member ID Points Tournaments Confederation       Country
# 0        9053155414  96798          14          Asia         China
# 1        9298044414  91753          20        Europe       Denmark
# 2        7726266513  90415          20          Asia         Korea
# 3        5620399389  84315          16          Asia      Malaysia
# 4        5967384812  83961          23          Asia         China
# ...  ..         ...    ...         ...           ...           ...
# 1424     9632969882     20           1        Europe         Spain
# 1425     6725155858     15           1        Europe       Belgium
# 1426     9970396561      2           1        Europe       Belgium
# 1427     8267255618      2           1       Oceania          Fiji
# 1428     1988993996      2           1       Oceania  COOK ISLANDS
#
# [1429 rows x 11 columns]

# %%
# Dropping the columns 'x1', 'x2', 'x3'
md_df = md_df.drop(columns=['x1', 'x2', 'x3'])

# %%
# Add 'Category' column
md_df['Category'] = 'MD'

# %%
md_df
# Out:
#       Rank Country Code                                          Player  \
# 0        1       CHNCHN            [CHN] LIANG Wei Keng[CHN] WANG Chang
# 1        2       DENDEN  [DEN] Kim ASTRUP[DEN] Anders Skaarup RASMUSSEN
# 2        3       KORKOR          [KOR] KANG Min Hyuk[KOR] SEO Seung Jae
# 3        4       MASMAS              [MAS] Aaron CHIA[MAS] SOH Wooi Yik
# 4        5       CHNCHN              [CHN] HE Ji Ting[CHN] REN Xiang Yu
# ...    ...          ...                                             ...
# 1424  1415       ESPESP       [ESP] Fernando CIVICO[ESP] Ricardo RETTIG
# 1425  1426       BELBEL         [BEL] Elias BRACKE[BEL] Senne HOUTHOOFD
# 1426  1427       BELBEL         [BEL] Charles FOUYN[BEL] Baptiste ROLIN
# 1427  1427       FIJFIJ               [FIJ] Jared CHUNG[FIJ] Robert LOO
# 1428  1427       COKCOK          [COK] Brendan LEE[COK] Emanuela MATAIO
#
#        Member ID Points Tournaments Confederation       Country Category
# 0     9053155414  96798          14          Asia         China       MD
# 1     9298044414  91753          20        Europe       Denmark       MD
# 2     7726266513  90415          20          Asia         Korea       MD
# 3     5620399389  84315          16          Asia      Malaysia       MD
# 4     5967384812  83961          23          Asia         China       MD
# ...          ...    ...         ...           ...           ...      ...
# 1424  9632969882     20           1        Europe         Spain       MD
# 1425  6725155858     15           1        Europe       Belgium       MD
# 1426  9970396561      2           1        Europe       Belgium       MD
# 1427  8267255618      2           1       Oceania          Fiji       MD
# 1428  1988993996      2           1       Oceania  COOK ISLANDS       MD
#
# [1429 rows x 9 columns]

# %%
#md_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\MD Player.csv', index = False)

# %% [markdown]
# ### **Women's Doubles**

# %%
# Women's Doubles URL, filtered by 100 results on each page.
wd_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42633&category=475&C475FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
# After checking with the filter by 100 results on each page.
# We need this info to work with the last page which doesn't contain 100 results as the previous ones.
wd_page_number = 11
wd_results = 1029

# %%
# From the Test above, now we know all the columns needed for the DataFrame. Create a list of column names.
list = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
# Create DataFrame
wd_df = pd.DataFrame(columns = list)
wd_df
# Out:
# Empty DataFrame
# Columns: [Rank, x1, x2, Country Code, Player, x3, Member ID, Points, Tournaments, Confederation, Country]
# Index: []

# %%
# Create a loop to add data to all pages in DataFrame 
# Loop through pages 1 to 19
for wd_page in range(1, wd_page_number +1):
    if wd_page < wd_page_number: # From pages 1-18 with 100 results on each page
        # Format the URL with the current page number
        wd_url = wd_base_url.format(wd_page)
        # Make a request to the URL
        wd_response = requests.get(wd_url, headers=headers)
        wd_soup = BeautifulSoup(wd_response.text, 'html.parser')
        wd_ranking_table = wd_soup.find('table', class_='ruler')
        wd_all_rows = wd_ranking_table.find_all('tr')[2:102]
        for wd_row in wd_all_rows:
            wd_row_data = wd_row.find_all('td')
            wd_individual_row_data = [wd_data.text.strip() for wd_data in wd_row_data]
            wd_length = len(wd_df)
            if wd_length < wd_results:
                wd_df.loc[wd_length] = wd_individual_row_data
            else:
                break
            
    else: # Page 19 with less than 100 results on this page
        # Format the URL with the current page number
        wd_url = wd_base_url.format(wd_page)
        # Make a request to the URL
        wd_response = requests.get(wd_url, headers=headers)
        wd_soup = BeautifulSoup(wd_response.text, 'html.parser')
        wd_ranking_table = wd_soup.find('table', class_='ruler')
        wd_all_rows = wd_ranking_table.find_all('tr')[2:(wd_results-((wd_page_number-1)*100) +2)]
        for wd_row in wd_all_rows:
            wd_row_data = wd_row.find_all('td')
            wd_individual_row_data = [wd_data.text.strip() for wd_data in wd_row_data]
            wd_length = len(wd_df)
            if wd_length < wd_results:
                wd_df.loc[wd_length] = wd_individual_row_data
            else:
                break

wd_df
# Out:
#       Rank x1 x2 Country Code  \
# 0        1     1       CHNCHN
# 1        2             CHNCHN
# 2        3             KORKOR
# 3        4             JPNJPN
# 4        5             CHNCHN
# ...    ... .. ..          ...
# 1024  1023             SVKSVK
# 1025  1026             TURTUR
# 1026  1026             SUISUI
# 1027  1026             PYFPYF
# 1028  1026             PYFPYF
#
#                                                Player x3   Member ID  Points  \
# 0                [CHN] CHEN Qing Chen[CHN] JIA Yi Fan     9412565144  104406
# 1                   [CHN] LIU Sheng Shu[CHN] TAN Ning     8159959880   99396
# 2                    [KOR] BAEK Ha Na[KOR] LEE So Hee     5670691292   98116
# 3             [JPN] Nami MATSUYAMA[JPN] Chiharu SHIDA     6521268282   91175
# 4                  [CHN] ZHANG Shu Xian[CHN] ZHENG Yu     8591485331   81491
# ...                                               ... ..         ...     ...
# 1024  [SVK] Johanka IVANOVICOVA[SVK] Olivia KADLECOVA     7760583887      40
# 1025          [TUR] Yasemen BEKTAS[TUR] Cansu ERCETIN     8662191818       2
# 1026    [SUI] Milena SCHNIDER[SUI] Jenjira STADELMANN     9752959566       2
# 1027            [PYF] Heirautea CURET[PYF] Esther TAU     9190687972       2
# 1028            [PYF] MéIissa MI YOU[PYF] Myriam SIAO     7944227024       2
#
#      Tournaments Confederation      Country
# 0             13          Asia        China
# 1             21          Asia        China
# 2             15          Asia        Korea
# 3             18          Asia        Japan
# 4             14          Asia        China
# ...          ...           ...          ...
# 1024           1        Europe     Slovakia
# 1025           1        Europe      Türkiye
# 1026           1        Europe  Switzerland
# 1027           1       Oceania       Tahiti
# 1028           1       Oceania       Tahiti
#
# [1029 rows x 11 columns]

# %%
# Dropping the columns 'x1', 'x2', 'x3'
wd_df = wd_df.drop(columns=['x1', 'x2', 'x3'])

# %%
# Add 'Category' column
wd_df['Category'] = 'WD'

# %%
wd_df
# Out:
#       Rank Country Code                                           Player  \
# 0        1       CHNCHN             [CHN] CHEN Qing Chen[CHN] JIA Yi Fan
# 1        2       CHNCHN                [CHN] LIU Sheng Shu[CHN] TAN Ning
# 2        3       KORKOR                 [KOR] BAEK Ha Na[KOR] LEE So Hee
# 3        4       JPNJPN          [JPN] Nami MATSUYAMA[JPN] Chiharu SHIDA
# 4        5       CHNCHN               [CHN] ZHANG Shu Xian[CHN] ZHENG Yu
# ...    ...          ...                                              ...
# 1024  1023       SVKSVK  [SVK] Johanka IVANOVICOVA[SVK] Olivia KADLECOVA
# 1025  1026       TURTUR          [TUR] Yasemen BEKTAS[TUR] Cansu ERCETIN
# 1026  1026       SUISUI    [SUI] Milena SCHNIDER[SUI] Jenjira STADELMANN
# 1027  1026       PYFPYF            [PYF] Heirautea CURET[PYF] Esther TAU
# 1028  1026       PYFPYF            [PYF] MéIissa MI YOU[PYF] Myriam SIAO
#
#        Member ID  Points Tournaments Confederation      Country Category
# 0     9412565144  104406          13          Asia        China       WD
# 1     8159959880   99396          21          Asia        China       WD
# 2     5670691292   98116          15          Asia        Korea       WD
# 3     6521268282   91175          18          Asia        Japan       WD
# 4     8591485331   81491          14          Asia        China       WD
# ...          ...     ...         ...           ...          ...      ...
# 1024  7760583887      40           1        Europe     Slovakia       WD
# 1025  8662191818       2           1        Europe      Türkiye       WD
# 1026  9752959566       2           1        Europe  Switzerland       WD
# 1027  9190687972       2           1       Oceania       Tahiti       WD
# 1028  7944227024       2           1       Oceania       Tahiti       WD
#
# [1029 rows x 9 columns]

# %%
#wd_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\WD Player.csv', index = False)

# %% [markdown]
# ### **Mixed Doubles**

# %%
# Mixed Doubles URL, filtered by 100 results on each page.
xd_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42633&category=476&C476FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
# After checking with the filter by 100 results on each page.
# We need this info to work with the last page which doesn't contain 100 results as the previous ones.
xd_page_number = 15
xd_results = 1402

# %%
# From the Test above, now we know all the columns needed for the DataFrame. Create a list of column names.
list = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']

# %%
# Create DataFrame
xd_df = pd.DataFrame(columns = list)
xd_df
# Out:
# Empty DataFrame
# Columns: [Rank, x1, x2, Country Code, Player, x3, Member ID, Points, Tournaments, Confederation, Country]
# Index: []

# %%
# Create a loop to add data to all pages in DataFrame 
# Loop through pages 1 to 19
for xd_page in range(1, xd_page_number +1):
    if xd_page < xd_page_number: # From pages 1-18 with 100 results on each page
        # Format the URL with the current page number
        xd_url = xd_base_url.format(xd_page)
        # Make a request to the URL
        xd_response = requests.get(xd_url, headers=headers)
        xd_soup = BeautifulSoup(xd_response.text, 'html.parser')
        xd_ranking_table = xd_soup.find('table', class_='ruler')
        xd_all_rows = xd_ranking_table.find_all('tr')[2:102]
        for xd_row in xd_all_rows:
            xd_row_data = xd_row.find_all('td')
            xd_individual_row_data = [xd_data.text.strip() for xd_data in xd_row_data]
            xd_length = len(xd_df)
            if xd_length < xd_results:
                xd_df.loc[xd_length] = xd_individual_row_data
            else:
                break
            
    else: # Page 19 with less than 100 results on this page
        # Format the URL with the current page number
        xd_url = xd_base_url.format(xd_page)
        # Make a request to the URL
        xd_response = requests.get(xd_url, headers=headers)
        xd_soup = BeautifulSoup(xd_response.text, 'html.parser')
        xd_ranking_table = xd_soup.find('table', class_='ruler')
        xd_all_rows = xd_ranking_table.find_all('tr')[2:(xd_results-((xd_page_number-1)*100) +2)]
        for xd_row in xd_all_rows:
            xd_row_data = xd_row.find_all('td')
            xd_individual_row_data = [xd_data.text.strip() for xd_data in xd_row_data]
            xd_length = len(xd_df)
            if xd_length < xd_results:
                xd_df.loc[xd_length] = xd_individual_row_data
            else:
                break

xd_df
# Out:
#       Rank x1 x2 Country Code  \
# 0        1             CHNCHN
# 1        2             CHNCHN
# 2        3             CHNCHN
# 3        4             KORKOR
# 4        5             JPNJPN
# ...    ... .. ..          ...
# 1397  1376             ISRMLT
# 1398  1376             ESTEST
# 1399  1376             DENDEN
# 1400  1376             MLTMLT
# 1401  1376             SCOEST
#
#                                                  Player x3   Member ID  \
# 0                [CHN] ZHENG Si Wei[CHN] HUANG Ya Qiong     8304663168
# 1               [CHN] FENG Yan Zhe[CHN] HUANG Dong Ping     6526789426
# 2                 [CHN] JIANG Zhen Bang[CHN] WEI Ya Xin     6302957246
# 3                 [KOR] SEO Seung Jae[KOR] CHAE Yu Jung     6651393074
# 4               [JPN] Yuta WATANABE[JPN] Arisa IGARASHI     5824079558
# ...                                                 ... ..         ...
# 1397               [ISR] Mark ARONCHIK[MLT] Emily ABELA     6982091376
# 1398               [EST] Dennis KUMAR[EST] Mia SAKARIAS     8564580515
# 1399  [DEN] Victor Roed SKOV[DEN] LæRke Wiktoria WENDEL     7843769090
# 1400          [MLT] Jeremy Mark GATT[MLT] Martina CLARK     3638768347
# 1401           [SCO] Evan KENNY[EST] Emilia SHAPOVALOVA     5657999601
#
#       Points Tournaments Confederation          Country
# 0     106850          13          Asia            China
# 1      99100          16          Asia            China
# 2      94050          19          Asia            China
# 3      83220          14          Asia            Korea
# 4      80970          14          Asia            Japan
# ...      ...         ...           ...              ...
# 1397      20           1        Europe      IsraelMalta
# 1398      20           1        Europe          Estonia
# 1399      20           1        Europe          Denmark
# 1400      20           1        Europe            Malta
# 1401      20           1        Europe  ScotlandEstonia
#
# [1402 rows x 11 columns]

# %%
# Dropping the columns 'x1', 'x2', 'x3'
xd_df = xd_df.drop(columns=['x1', 'x2', 'x3'])

# %%
# Add 'Category' column
xd_df['Category'] = 'XD'

# %%
xd_df
# Out:
#       Rank Country Code                                             Player  \
# 0        1       CHNCHN             [CHN] ZHENG Si Wei[CHN] HUANG Ya Qiong
# 1        2       CHNCHN            [CHN] FENG Yan Zhe[CHN] HUANG Dong Ping
# 2        3       CHNCHN              [CHN] JIANG Zhen Bang[CHN] WEI Ya Xin
# 3        4       KORKOR              [KOR] SEO Seung Jae[KOR] CHAE Yu Jung
# 4        5       JPNJPN            [JPN] Yuta WATANABE[JPN] Arisa IGARASHI
# ...    ...          ...                                                ...
# 1397  1376       ISRMLT               [ISR] Mark ARONCHIK[MLT] Emily ABELA
# 1398  1376       ESTEST               [EST] Dennis KUMAR[EST] Mia SAKARIAS
# 1399  1376       DENDEN  [DEN] Victor Roed SKOV[DEN] LæRke Wiktoria WENDEL
# 1400  1376       MLTMLT          [MLT] Jeremy Mark GATT[MLT] Martina CLARK
# 1401  1376       SCOEST           [SCO] Evan KENNY[EST] Emilia SHAPOVALOVA
#
#        Member ID  Points Tournaments Confederation          Country Category
# 0     8304663168  106850          13          Asia            China       XD
# 1     6526789426   99100          16          Asia            China       XD
# 2     6302957246   94050          19          Asia            China       XD
# 3     6651393074   83220          14          Asia            Korea       XD
# 4     5824079558   80970          14          Asia            Japan       XD
# ...          ...     ...         ...           ...              ...      ...
# 1397  6982091376      20           1        Europe      IsraelMalta       XD
# 1398  8564580515      20           1        Europe          Estonia       XD
# 1399  7843769090      20           1        Europe          Denmark       XD
# 1400  3638768347      20           1        Europe            Malta       XD
# 1401  5657999601      20           1        Europe  ScotlandEstonia       XD
#
# [1402 rows x 9 columns]

# %%
#xd_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\XD Player.csv', index = False)

# %%
# List of DataFrames to concatenate
dfs = [ms_df, ws_df, md_df, wd_df, xd_df]

# Concatenate the DataFrames
all_players = pd.concat(dfs, ignore_index=True)

# Display the resulting DataFrame
all_players
# Out:
#       Rank Country Code                                             Player  \
# 0        1          CHN                                    [CHN] SHI Yu Qi
# 1        2          DEN                               [DEN] Viktor AXELSEN
# 2        3          DEN                              [DEN] Anders ANTONSEN
# 3        4          JPN                                [JPN] Kodai NARAOKA
# 4        5          MAS                                  [MAS] LEE Zii Jia
# ...    ...          ...                                                ...
# 6910  1376       ISRMLT               [ISR] Mark ARONCHIK[MLT] Emily ABELA
# 6911  1376       ESTEST               [EST] Dennis KUMAR[EST] Mia SAKARIAS
# 6912  1376       DENDEN  [DEN] Victor Roed SKOV[DEN] LæRke Wiktoria WENDEL
# 6913  1376       MLTMLT          [MLT] Jeremy Mark GATT[MLT] Martina CLARK
# 6914  1376       SCOEST           [SCO] Evan KENNY[EST] Emilia SHAPOVALOVA
#
#        Member ID  Points Tournaments Confederation          Country Category
# 0          57945  101815          18          Asia            China       MS
# 1          25831   93790          14        Europe          Denmark       MS
# 2          91554   84241          22        Europe          Denmark       MS
# 3          62063   84197          22          Asia            Japan       MS
# 4          81561   83716          22          Asia         Malaysia       MS
# ...          ...     ...         ...           ...              ...      ...
# 6910  6982091376      20           1        Europe      IsraelMalta       XD
# 6911  8564580515      20           1        Europe          Estonia       XD
# 6912  7843769090      20           1        Europe          Denmark       XD
# 6913  3638768347      20           1        Europe            Malta       XD
# 6914  5657999601      20           1        Europe  ScotlandEstonia       XD
#
# [6915 rows x 9 columns]

# %%
all_players.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\All_Players.csv', index = False)

# %%
df1 = pd.read_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\All_Players.csv')
df1
# Out:
#       Rank Country Code                                             Player  \
# 0        1          CHN                                    [CHN] SHI Yu Qi
# 1        2          DEN                               [DEN] Viktor AXELSEN
# 2        3          DEN                              [DEN] Anders ANTONSEN
# 3        4          JPN                                [JPN] Kodai NARAOKA
# 4        5          MAS                                  [MAS] LEE Zii Jia
# ...    ...          ...                                                ...
# 6910  1376       ISRMLT               [ISR] Mark ARONCHIK[MLT] Emily ABELA
# 6911  1376       ESTEST               [EST] Dennis KUMAR[EST] Mia SAKARIAS
# 6912  1376       DENDEN  [DEN] Victor Roed SKOV[DEN] LæRke Wiktoria WENDEL
# 6913  1376       MLTMLT          [MLT] Jeremy Mark GATT[MLT] Martina CLARK
# 6914  1376       SCOEST           [SCO] Evan KENNY[EST] Emilia SHAPOVALOVA
#
#        Member ID  Points  Tournaments Confederation          Country Category
# 0          57945  101815           18          Asia            China       MS
# 1          25831   93790           14        Europe          Denmark       MS
# 2          91554   84241           22        Europe          Denmark       MS
# 3          62063   84197           22          Asia            Japan       MS
# 4          81561   83716           22          Asia         Malaysia       MS
# ...          ...     ...          ...           ...              ...      ...
# 6910  6982091376      20            1        Europe      IsraelMalta       XD
# 6911  8564580515      20            1        Europe          Estonia       XD
# 6912  7843769090      20            1        Europe          Denmark       XD
# 6913  3638768347      20            1        Europe            Malta       XD
# 6914  5657999601      20            1        Europe  ScotlandEstonia       XD
#
# [6915 rows x 9 columns]

# %%
# Function to format the 6-character values
def format_category(value):
    if len(value) == 6:
        return value[:3] + '/' + value[3:]
    return value

# Apply the function to the 'Country Code' column
df1['Country Code'] = df1['Country Code'].apply(format_category)

# Display the resulting DataFrame
df1
# Out:
#       Rank Country Code                                             Player  \
# 0        1          CHN                                    [CHN] SHI Yu Qi
# 1        2          DEN                               [DEN] Viktor AXELSEN
# 2        3          DEN                              [DEN] Anders ANTONSEN
# 3        4          JPN                                [JPN] Kodai NARAOKA
# 4        5          MAS                                  [MAS] LEE Zii Jia
# ...    ...          ...                                                ...
# 6910  1376      ISR/MLT               [ISR] Mark ARONCHIK[MLT] Emily ABELA
# 6911  1376      EST/EST               [EST] Dennis KUMAR[EST] Mia SAKARIAS
# 6912  1376      DEN/DEN  [DEN] Victor Roed SKOV[DEN] LæRke Wiktoria WENDEL
# 6913  1376      MLT/MLT          [MLT] Jeremy Mark GATT[MLT] Martina CLARK
# 6914  1376      SCO/EST           [SCO] Evan KENNY[EST] Emilia SHAPOVALOVA
#
#        Member ID  Points  Tournaments Confederation          Country Category
# 0          57945  101815           18          Asia            China       MS
# 1          25831   93790           14        Europe          Denmark       MS
# 2          91554   84241           22        Europe          Denmark       MS
# 3          62063   84197           22          Asia            Japan       MS
# 4          81561   83716           22          Asia         Malaysia       MS
# ...          ...     ...          ...           ...              ...      ...
# 6910  6982091376      20            1        Europe      IsraelMalta       XD
# 6911  8564580515      20            1        Europe          Estonia       XD
# 6912  7843769090      20            1        Europe          Denmark       XD
# 6913  3638768347      20            1        Europe            Malta       XD
# 6914  5657999601      20            1        Europe  ScotlandEstonia       XD
#
# [6915 rows x 9 columns]

# %%
import re

# %%
# Function to process the 'Player' column
def format_player(value):
    # Add '/' before the second '[yyy]'
    value = re.sub(r'(\[\w{3}\])([^[]+)(\[\w{3}\])', r'\1\2/\3', value)
    # Remove all occurrences of '[xxx]'
    value = re.sub(r'\[\w{3}\]', '', value)
    # Remove any leading/trailing whitespace
    return value.strip()

# Apply the function to the 'Player' column
df1['Player'] = df1['Player'].apply(format_player)

# Display the resulting DataFrame
df1
# Out:
#       Rank Country Code                                   Player   Member ID  \
# 0        1          CHN                                SHI Yu Qi       57945
# 1        2          DEN                           Viktor AXELSEN       25831
# 2        3          DEN                          Anders ANTONSEN       91554
# 3        4          JPN                            Kodai NARAOKA       62063
# 4        5          MAS                              LEE Zii Jia       81561
# ...    ...          ...                                      ...         ...
# 6910  1376      ISR/MLT               Mark ARONCHIK/ Emily ABELA  6982091376
# 6911  1376      EST/EST               Dennis KUMAR/ Mia SAKARIAS  8564580515
# 6912  1376      DEN/DEN  Victor Roed SKOV/ LæRke Wiktoria WENDEL  7843769090
# 6913  1376      MLT/MLT          Jeremy Mark GATT/ Martina CLARK  3638768347
# 6914  1376      SCO/EST           Evan KENNY/ Emilia SHAPOVALOVA  5657999601
#
#       Points  Tournaments Confederation          Country Category
# 0     101815           18          Asia            China       MS
# 1      93790           14        Europe          Denmark       MS
# 2      84241           22        Europe          Denmark       MS
# 3      84197           22          Asia            Japan       MS
# 4      83716           22          Asia         Malaysia       MS
# ...      ...          ...           ...              ...      ...
# 6910      20            1        Europe      IsraelMalta       XD
# 6911      20            1        Europe          Estonia       XD
# 6912      20            1        Europe          Denmark       XD
# 6913      20            1        Europe            Malta       XD
# 6914      20            1        Europe  ScotlandEstonia       XD
#
# [6915 rows x 9 columns]

# %%
df1['Country']
# Out:
# 0                 China
# 1               Denmark
# 2               Denmark
# 3                 Japan
# 4              Malaysia
#              ...
# 6910        IsraelMalta
# 6911            Estonia
# 6912            Denmark
# 6913              Malta
# 6914    ScotlandEstonia
# Name: Country, Length: 6915, dtype: object

# %%
country_list = df1['Country'].tolist()
country_list
# Out:
# ['China',
#  'Denmark',
#  'Denmark',
#  'Japan',
#  'Malaysia',
#  'China',
#  'Indonesia',
#  'Thailand',
#  'Chinese Taipei',
#  'Indonesia',
#  'Singapore',
#  'Chinese Taipei',
#  'Japan',
#  'Japan',
#  'China',
#  'Hong Kong China',
#  'China',
#  'India',
#  'France',
#  'India',
#  'Hong Kong China',
#  'France',
#  'China',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Canada',
#  'France',
#  'Denmark',
#  'Malaysia',
#  'Japan',
#  'Indonesia',
#  'Malaysia',
#  'Japan',
#  'Chinese Taipei',
#  'India',
#  'Thailand',
#  'Chinese Taipei',
#  'India',
#  'Korea',
#  'Singapore',
#  'India',
#  'Ireland',
#  'Denmark',
#  'India',
#  'Indonesia',
#  'Hong Kong China',
#  'Denmark',
#  'France',
#  'Belgium',
#  'Japan',
#  'Malaysia',
#  'Netherlands',
#  'Brazil',
#  'Japan',
#  'Guatemala',
#  'China',
#  'Indonesia',
#  'India',
#  'Malaysia',
#  'Finland',
#  'Vietnam',
#  'Czechia',
#  'China',
#  'El Salvador',
#  'Azerbaijan',
#  'Finland',
#  'Thailand',
#  'Spain',
#  'Malaysia',
#  'India',
#  'Israel',
#  'Brazil',
#  'Vietnam',
#  'Chinese Taipei',
#  'Kazakhstan',
#  'India',
#  'India',
#  'Italy',
#  'Sri Lanka',
#  'Indonesia',
#  'India',
#  'Chinese Taipei',
#  'Mexico',
#  'U.S.A.',
#  'Indonesia',
#  'Chinese Taipei',
#  'India',
#  'Chinese Taipei',
#  'Germany',
#  'Netherlands',
#  'India',
#  'Canada',
#  'Mauritius',
#  'Hong Kong China',
#  'Malaysia',
#  'India',
#  'Peru',
#  'Germany',
#  'France',
#  'Switzerland',
#  'Denmark',
#  'Israel',
#  'France',
#  'England',
#  'Italy',
#  'India',
#  'Canada',
#  'Germany',
#  'Nigeria',
#  'Singapore',
#  'Chinese Taipei',
#  'Japan',
#  'India',
#  'Japan',
#  'India',
#  'Indonesia',
#  'Austria',
#  'UNITED ARAB EMIRATES',
#  'India',
#  'Malaysia',
#  'Denmark',
#  'Thailand',
#  'Guatemala',
#  'Chinese Taipei',
#  'Malaysia',
#  'Japan',
#  'India',
#  'U.S.A.',
#  'India',
#  'Spain',
#  'Korea',
#  'Sweden',
#  'India',
#  'Germany',
#  'China',
#  'Germany',
#  'Denmark',
#  'Malaysia',
#  'U.S.A.',
#  'India',
#  'Norway',
#  'Malaysia',
#  'Indonesia',
#  'Indonesia',
#  'Croatia',
#  'Indonesia',
#  'Australia',
#  'New Zealand',
#  'France',
#  'Austria',
#  'Egypt',
#  'France',
#  'Switzerland',
#  'India',
#  'Australia',
#  'England',
#  'Jamaica',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Denmark',
#  'France',
#  'Nepal',
#  'Korea',
#  'Australia',
#  'Macau China',
#  'India',
#  'Japan',
#  'Sweden',
#  'Mexico',
#  'India',
#  'France',
#  'Poland',
#  'Sri Lanka',
#  'England',
#  'Austria',
#  'Mexico',
#  'Belgium',
#  'India',
#  'India',
#  'India',
#  'Switzerland',
#  'Germany',
#  'Korea',
#  'Malaysia',
#  'Indonesia',
#  'Slovakia',
#  'Japan',
#  'India',
#  'Japan',
#  'India',
#  'Japan',
#  'India',
#  'Hungary',
#  'Algeria',
#  'Denmark',
#  'Sri Lanka',
#  'Thailand',
#  'Chinese Taipei',
#  'India',
#  'Denmark',
#  'Australia',
#  'Poland',
#  'France',
#  'England',
#  'Denmark',
#  'India',
#  'France',
#  'SAUDI ARABIA',
#  'Portugal',
#  'England',
#  'South Africa',
#  'Chinese Taipei',
#  'Canada',
#  'Japan',
#  'El Salvador',
#  'Australia',
#  'Korea',
#  'Germany',
#  'East Timor',
#  'Switzerland',
#  'India',
#  'Zambia',
#  'Thailand',
#  'Poland',
#  'U.S.A.',
#  'France',
#  'Korea',
#  'India',
#  'Malaysia',
#  'Italy',
#  'Nigeria',
#  'Malaysia',
#  'UNITED ARAB EMIRATES',
#  'Malaysia',
#  'Denmark',
#  'Paraguay',
#  'Canada',
#  'Indonesia',
#  'Indonesia',
#  'Canada',
#  'Malta',
#  'Thailand',
#  'Thailand',
#  'India',
#  'Malaysia',
#  'India',
#  'Belgium',
#  'Germany',
#  'China',
#  'England',
#  'Myanmar',
#  'Nigeria',
#  'India',
#  'Suriname',
#  'Australia',
#  'Indonesia',
#  'Malaysia',
#  'Indonesia',
#  'Canada',
#  'India',
#  'France',
#  'India',
#  'U.S.A.',
#  'Canada',
#  'Maldives',
#  'Chinese Taipei',
#  'Canada',
#  'India',
#  'Indonesia',
#  'Czechia',
#  'Denmark',
#  'China',
#  'Slovenia',
#  'Mexico',
#  'Scotland',
#  'Spain',
#  'Guatemala',
#  'India',
#  'Germany',
#  'India',
#  'Myanmar',
#  'Malaysia',
#  'Argentina',
#  'Denmark',
#  'Ukraine',
#  'Canada',
#  'Korea',
#  'Indonesia',
#  'India',
#  'Argentina',
#  'Ecuador',
#  'Guatemala',
#  'Portugal',
#  'Japan',
#  'Italy',
#  'Venezuela',
#  'Egypt',
#  'Azerbaijan',
#  'Israel',
#  'Philippines',
#  'Denmark',
#  'Cambodia',
#  'Mauritius',
#  'Korea',
#  'Australia',
#  'Australia',
#  'Malaysia',
#  'U.S.A.',
#  'Costa Rica',
#  'Poland',
#  'MOROCCO Independent',
#  'Nigeria',
#  'Singapore',
#  'Maldives',
#  'Malaysia',
#  'Chinese Taipei',
#  'Uganda',
#  'Malaysia',
#  'U.S.A.',
#  'Brazil',
#  'India',
#  'Spain',
#  'Indonesia',
#  'Mauritius',
#  'Algeria',
#  'Canada',
#  'Australia',
#  'Canada',
#  'Japan',
#  'Poland',
#  'Estonia',
#  'Algeria',
#  'Singapore',
#  'India',
#  'Sweden',
#  'Switzerland',
#  'Dominican Republic',
#  'England',
#  'France',
#  'New Zealand',
#  'El Salvador',
#  'Denmark',
#  'India',
#  'Netherlands',
#  'India',
#  'India',
#  'India',
#  'Cuba',
#  'India',
#  'Korea',
#  'Australia',
#  'India',
#  'Sri Lanka',
#  'UNITED ARAB EMIRATES',
#  'U.S.A.',
#  'Austria',
#  'Estonia',
#  'Malaysia',
#  'Indonesia',
#  'Sri Lanka',
#  'England',
#  'India',
#  'India',
#  'Poland',
#  'South Africa',
#  'Mauritius',
#  'Denmark',
#  'France',
#  'Malaysia',
#  'Australia',
#  'Colombia',
#  'India',
#  'Barbados',
#  'Zambia',
#  'India',
#  'Bahrain',
#  'India',
#  'Finland',
#  'India',
#  'Finland',
#  'Japan',
#  'Czechia',
#  'India',
#  'Japan',
#  'Belgium',
#  'Algeria',
#  'Norway',
#  'Croatia',
#  'India',
#  'India',
#  'Chinese Taipei',
#  'New Zealand',
#  'Germany',
#  'China',
#  'Canada',
#  'Japan',
#  'Egypt',
#  'Algeria',
#  'Mauritius',
#  'India',
#  'India',
#  'India',
#  'Trinidad & Tobago',
#  'Japan',
#  'Chinese Taipei',
#  'EQUATORIAL GUINEA',
#  'Nigeria',
#  'India',
#  'Canada',
#  'Chinese Taipei',
#  'India',
#  'India',
#  'India',
#  'Poland',
#  'Canada',
#  'Australia',
#  'Indonesia',
#  'Finland',
#  'UNITED ARAB EMIRATES',
#  'England',
#  'Egypt',
#  'Uganda',
#  'Hungary',
#  'India',
#  'Italy',
#  'Netherlands',
#  'Brunei Darussalam',
#  'Australia',
#  'Portugal',
#  'Scotland',
#  'Sweden',
#  'Ghana',
#  'Chinese Taipei',
#  'Malaysia',
#  'India',
#  'Indonesia',
#  'Canada',
#  'Italy',
#  'Australia',
#  'India',
#  'Sweden',
#  'Malaysia',
#  'U.S.A.',
#  'Netherlands',
#  'Bulgaria',
#  'Indonesia',
#  'U.S.A.',
#  'Cuba',
#  'Poland',
#  'India',
#  'Peru',
#  'U.S.A.',
#  'Canada',
#  'Malaysia',
#  'U.S.A.',
#  'Malaysia',
#  'China',
#  'Korea',
#  'Canada',
#  'New Zealand',
#  'Chinese Taipei',
#  'India',
#  'Czechia',
#  'Iran',
#  'Malaysia',
#  'China',
#  'Hong Kong China',
#  'Netherlands',
#  'India',
#  'Malaysia',
#  'Bulgaria',
#  'Nepal',
#  'Mauritius',
#  'Chinese Taipei',
#  'Malaysia',
#  'Spain',
#  'Thailand',
#  'Vietnam',
#  'India',
#  'India',
#  'Netherlands',
#  'Peru',
#  'Malaysia',
#  'U.S.A.',
#  'Indonesia',
#  'Canada',
#  'Guatemala',
#  'MOROCCO Independent',
#  'England',
#  'Australia',
#  'U.S.A.',
#  'Canada',
#  'India',
#  'Estonia',
#  'Belgium',
#  'Finland',
#  'Ghana',
#  'Iran',
#  'Chinese Taipei',
#  'Malta',
#  'Malaysia',
#  'India',
#  'Malaysia',
#  'Uganda',
#  'Canada',
#  'India',
#  'Bhutan',
#  'Malaysia',
#  'Switzerland',
#  'Indonesia',
#  'Jordan',
#  'Egypt',
#  'Denmark',
#  'Canada',
#  'U.S.A.',
#  'Sweden',
#  'Scotland',
#  'Canada',
#  'Chinese Taipei',
#  'India',
#  'Malaysia',
#  'Dominican Republic',
#  'Chile',
#  'Chile',
#  'Peru',
#  'Jamaica',
#  'Chile',
#  'Sweden',
#  'France',
#  'Thailand',
#  'Malaysia',
#  'Zambia',
#  'Canada',
#  'South Africa',
#  'Thailand',
#  'Mexico',
#  'Chinese Taipei',
#  'Canada',
#  'Philippines',
#  'Maldives',
#  'Chinese Taipei',
#  'England',
#  'France',
#  'Bulgaria',
#  'Tahiti',
#  'England',
#  'India',
#  'Denmark',
#  'Uganda',
#  'Canada',
#  'Malaysia',
#  'India',
#  'Uganda',
#  'Venezuela',
#  'Venezuela',
#  'U.S.A.',
#  'Canada',
#  'Nigeria',
#  'Ghana',
#  'Ligue Nouvelle Badminton REUNION',
#  'New Zealand',
#  'Nigeria',
#  'Australia',
#  'Kazakhstan',
#  'France',
#  'England',
#  'Malaysia',
#  'Canada',
#  'Egypt',
#  'Australia',
#  'Australia',
#  'India',
#  'Sweden',
#  'Syrian Arab Republic',
#  'Mauritius',
#  'Venezuela',
#  'France',
#  'France',
#  'Indonesia',
#  'Venezuela',
#  'Venezuela',
#  'Indonesia',
#  'Mauritius',
#  'Denmark',
#  'Japan',
#  'India',
#  'Guam National Badminton Federation',
#  'Malaysia',
#  'England',
#  'India',
#  'Guatemala',
#  'Peru',
#  'Vietnam',
#  'Malaysia',
#  'Canada',
#  'Hungary',
#  'India',
#  'England',
#  'SAUDI ARABIA',
#  'COOK ISLANDS',
#  'Malaysia',
#  'SAUDI ARABIA',
#  'Uganda',
#  'Suriname',
#  'El Salvador',
#  'Bangladesh',
#  'Uganda',
#  'Ireland',
#  'England',
#  'Australia',
#  'Macau China',
#  'Germany',
#  'U.S.A.',
#  'China',
#  'China',
#  'Indonesia',
#  'Nepal',
#  'Thailand',
#  'NORTHERN MARIANAS',
#  'NORTHERN MARIANAS',
#  'Malaysia',
#  'Denmark',
#  'Suriname',
#  'Venezuela',
#  'Venezuela',
#  'Suriname',
#  'Mauritius',
#  'Belgium',
#  'Austria',
#  'Costa Rica',
#  'Brazil',
#  'France',
#  'Mauritius',
#  'Guatemala',
#  'India',
#  'New Zealand',
#  'U.S.A.',
#  'Pakistan',
#  'Mongolia',
#  'Pakistan',
#  'Nepal',
#  'Mongolia',
#  'East Timor',
#  'Bhutan',
#  'Australia',
#  'Mauritius',
#  'FGU FRENCH GUIANA',
#  'Canada',
#  'Finland',
#  'UNITED ARAB EMIRATES',
#  'Sweden',
#  'Kazakhstan',
#  'Australia',
#  'Indonesia',
#  'Ligue Nouvelle Badminton REUNION',
#  'Ligue Nouvelle Badminton REUNION',
#  'Malaysia',
#  'India',
#  'Chinese Taipei',
#  'Malaysia',
#  'India',
#  'Indonesia',
#  'India',
#  'Kazakhstan',
#  'Türkiye',
#  'Denmark',
#  'Uganda',
#  'Mexico',
#  'France',
#  'India',
#  'England',
#  'Australia',
#  'Malaysia',
#  'Denmark',
#  'England',
#  'India',
#  'Sweden',
#  'Korea',
#  'Sri Lanka',
#  'Thailand',
#  'Malaysia',
#  'New Zealand',
#  'Chinese Taipei',
#  'England',
#  'Australia',
#  'Netherlands',
#  'Türkiye',
#  'India',
#  'Uganda',
#  'Kazakhstan',
#  'Kazakhstan',
#  'New Zealand',
#  'Switzerland',
#  'Guatemala',
#  'Australia',
#  'India',
#  'Malaysia',
#  'Egypt',
#  'Germany',
#  'Guatemala',
#  'Spain',
#  'Mauritius',
#  'India',
#  'Mexico',
#  'Brazil',
#  'Portugal',
#  'Malaysia',
#  'India',
#  'Australia',
#  'New Zealand',
#  'New Zealand',
#  'Portugal',
#  'Myanmar',
#  'Suriname',
#  'Australia',
#  'Iran',
#  'Kazakhstan',
#  'Dominican Republic',
#  'Australia',
#  'Nigeria',
#  'Nigeria',
#  'Ligue Nouvelle Badminton REUNION',
#  'Suriname',
#  'Zambia',
#  'Iran',
#  'Nigeria',
#  'Nigeria',
#  'Uzbekistan',
#  'Iran',
#  'Eritrea',
#  'Nigeria',
#  'Australia',
#  'South Africa',
#  'Australia',
#  'BUR Burkina Faso',
#  'Ligue Nouvelle Badminton REUNION',
#  'Ligue Nouvelle Badminton REUNION',
#  'Madagascar',
#  'Paraguay',
#  'Nigeria',
#  'Canada',
#  'New Zealand',
#  'Korea',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Cuba',
#  'Guam National Badminton Federation',
#  'Nigeria',
#  'TOGO Badminton Association',
#  'India',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'India',
#  'FGU FRENCH GUIANA',
#  'FGU FRENCH GUIANA',
#  'Iran',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'U.S.A.',
#  'Venezuela',
#  'Nigeria',
#  'Nigeria',
#  'India',
#  'India',
#  'England',
#  'Zimbabwe',
#  'Sweden',
#  'Iran',
#  'Zambia',
#  'Cameroon',
#  'Cameroon',
#  'Uzbekistan',
#  'Uzbekistan',
#  'India',
#  'Peru',
#  'Zimbabwe',
#  'Mexico',
#  'Venezuela',
#  'Venezuela',
#  'England',
#  'Canada',
#  'India',
#  'India',
#  'Sweden',
#  'Singapore',
#  'Canada',
#  'U.S.A.',
#  'Scotland',
#  'India',
#  'India',
#  'Venezuela',
#  'Cameroon',
#  'Serbia',
#  'Malaysia',
#  'New Zealand',
#  'Finland',
#  'Mexico',
#  'Malaysia',
#  'Bulgaria',
#  'UNITED ARAB EMIRATES',
#  'China',
#  'Australia',
#  'Cameroon',
#  'Uganda',
#  'India',
#  'Portugal',
#  'England',
#  'Hungary',
#  'Guatemala',
#  'Kazakhstan',
#  'Mexico',
#  'Mexico',
#  'Canada',
#  'Uzbekistan',
#  'Kazakhstan',
#  'NORTHERN MARIANAS',
#  'Malaysia',
#  'NORTHERN MARIANAS',
#  'Kazakhstan',
#  'NORTHERN MARIANAS',
#  'Guam National Badminton Federation',
#  'NORTHERN MARIANAS',
#  'NORTHERN MARIANAS',
#  'Canada',
#  'Switzerland',
#  'Paraguay',
#  'Vietnam',
#  'Poland',
#  'Sri Lanka',
#  'Sweden',
#  'Guatemala',
#  'Maldives',
#  'Poland',
#  'Malaysia',
#  'England',
#  'Slovenia',
#  'Vietnam',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Denmark',
#  'Algeria',
#  'Malaysia',
#  'Ukraine',
#  'Thailand',
#  'Ukraine',
#  'Denmark',
#  'Finland',
#  'Denmark',
#  'Malaysia',
#  'Uganda',
#  'Uganda',
#  'Guatemala',
#  'Botswana',
#  'Guatemala',
#  'England',
#  'Guyana',
#  'Mexico',
#  'India',
#  'Denmark',
#  'Botswana',
#  'Cuba',
#  'Suriname',
#  'FGU FRENCH GUIANA',
#  'FGU FRENCH GUIANA',
#  'Suriname',
#  'Cuba',
#  'Cuba',
#  'Venezuela',
#  'Venezuela',
#  'Canada',
#  'U.S.A.',
#  'India',
#  'India',
#  'Malaysia',
#  'Indonesia',
#  'Austria',
#  'Slovenia',
#  'Malaysia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Maldives',
#  'Switzerland',
#  'Ligue Nouvelle Badminton REUNION',
#  'Austria',
#  'Malaysia',
#  'Belgium',
#  'Denmark',
#  'Suriname',
#  'Guatemala',
#  'Dominican Republic',
#  'National Olympic Committee KENYA',
#  'Algeria',
#  'Egypt',
#  'Algeria',
#  'Algeria',
#  'Uganda',
#  'National Olympic Committee KENYA',
#  'U.S.A.',
#  'Canada',
#  'Vietnam',
#  'Vietnam',
#  'Vietnam',
#  'Guatemala',
#  'Thailand',
#  'Zambia',
#  'Uzbekistan',
#  'Dominican Republic',
#  'Trinidad & Tobago',
#  'Trinidad & Tobago',
#  'Trinidad & Tobago',
#  'Indonesia',
#  'Venezuela',
#  'Venezuela',
#  'Venezuela',
#  'Venezuela',
#  'Venezuela',
#  'Venezuela',
#  'Australia',
#  'Korea',
#  'Australia',
#  'Algeria',
#  'Algeria',
#  'Vietnam',
#  'Trinidad & Tobago',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'Trinidad & Tobago',
#  'Trinidad & Tobago',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'Suriname',
#  'U.S.A.',
#  'U.S.A.',
#  'U.S.A.',
#  'U.S.A.',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'India',
#  'India',
#  'Germany',
#  'Fiji',
#  'Australia',
#  'Venezuela',
#  'India',
#  'Australia',
#  'Australia',
#  'Ireland',
#  'Netherlands',
#  'Scotland',
#  'France',
#  'Singapore',
#  'Malaysia',
#  'Malaysia',
#  'China',
#  'France',
#  'Slovenia',
#  'Luxembourg',
#  'Ireland',
#  'Austria',
#  'U.S.A.',
#  'Slovenia',
#  'Slovenia',
#  'Azerbaijan',
#  'Cyprus',
#  'Ukraine',
#  'Scotland',
#  'Bahrain',
#  'Malaysia',
#  'England',
#  'Chinese Taipei',
#  'Vietnam',
#  'Luxembourg',
#  'Norway',
#  'India',
#  'India',
#  'India',
#  'India',
#  'England',
#  'India',
#  'England',
#  'India',
#  'Azerbaijan',
#  'England',
#  'Czechia',
#  ...]

# %%
# Function to separate concatenated country names
def separate_countries(value):
    for country in country_list:
        if value.startswith(country):
            rest = value[len(country):]
            if rest and any(rest.startswith(other_country) for other_country in country_list):
                return country + '/' + rest
    return value

# Apply the function to the 'Country' column
df1['Country'] = df1['Country'].apply(separate_countries)

# Display the resulting DataFrame
df1
# Out:
#       Rank Country Code                                   Player   Member ID  \
# 0        1          CHN                                SHI Yu Qi       57945
# 1        2          DEN                           Viktor AXELSEN       25831
# 2        3          DEN                          Anders ANTONSEN       91554
# 3        4          JPN                            Kodai NARAOKA       62063
# 4        5          MAS                              LEE Zii Jia       81561
# ...    ...          ...                                      ...         ...
# 6910  1376      ISR/MLT               Mark ARONCHIK/ Emily ABELA  6982091376
# 6911  1376      EST/EST               Dennis KUMAR/ Mia SAKARIAS  8564580515
# 6912  1376      DEN/DEN  Victor Roed SKOV/ LæRke Wiktoria WENDEL  7843769090
# 6913  1376      MLT/MLT          Jeremy Mark GATT/ Martina CLARK  3638768347
# 6914  1376      SCO/EST           Evan KENNY/ Emilia SHAPOVALOVA  5657999601
#
#       Points  Tournaments Confederation           Country Category
# 0     101815           18          Asia             China       MS
# 1      93790           14        Europe           Denmark       MS
# 2      84241           22        Europe           Denmark       MS
# 3      84197           22          Asia             Japan       MS
# 4      83716           22          Asia          Malaysia       MS
# ...      ...          ...           ...               ...      ...
# 6910      20            1        Europe      Israel/Malta       XD
# 6911      20            1        Europe           Estonia       XD
# 6912      20            1        Europe           Denmark       XD
# 6913      20            1        Europe             Malta       XD
# 6914      20            1        Europe  Scotland/Estonia       XD
#
# [6915 rows x 9 columns]

# %%
df1.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\Player list.csv', index = False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's Singles URL, Filtered by 100 results on each page.
ms_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this trip to work with the last page which doesn't contain 100 results as the previous ones.
ms_page_number = 1
ms_results = 1831

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
ms_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for ms_page in range(1, ms_page_number + 20):
    if ms_page < 19:  # Pages 1-18 with 100 results on each page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = [data.text.strip() if data.find('a') is None else data.find('a')['href'] for data in row_data]
            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data
            
            if len(ms_df) >= ms_results:
                break
    else:  # Page 19 with less than 100 results on this page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(ms_results - ((ms_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = [data.text.strip() if data.find('a') is None else data.find('a')['href'] for data in row_data]
            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data

            if len(ms_df) >= ms_results:
                break

# Display the resulting DataFrame
print(ms_df)
# Out:
#       Rank x1 x2 Country Code                               Player  \
# 0        1                CHN   player.aspx?id=42511&player=990139
# 1        2                DEN   player.aspx?id=42511&player=147387
# 2        3                DEN   player.aspx?id=42511&player=396249
# 3        4                JPN  player.aspx?id=42511&player=1561759
# 4        5                MAS   player.aspx?id=42511&player=318753
# ...    ... .. ..          ...                                  ...
# 1826  1767                UGA  player.aspx?id=42511&player=7270299
# 1827  1767                UGA  player.aspx?id=42511&player=7798125
# 1828  1767                UGA  player.aspx?id=42511&player=6354531
# 1829  1767                UGA  player.aspx?id=42511&player=7272031
# 1830  1767                UGA  player.aspx?id=42511&player=7274677
#
#                                                      x3 Member ID  Points  \
# 0     /player-profile/38CBD70E-A643-4170-9E6A-288634...     57945  101815
# 1     /player-profile/3BF0C3EA-7BFB-4CC9-A955-3712D8...     25831   93790
# 2     /player-profile/473960FD-334B-476F-9821-8ED939...     91554   84241
# 3     /player-profile/7804BE61-F954-4C46-9E72-FED84B...     62063   84197
# 4     /player-profile/21E9EAF0-5C86-416F-A942-C3ECA0...     81561   83716
# ...                                                 ...       ...     ...
# 1826  /player-profile/7D272D8F-8011-4BB0-AA9E-9C79FE...     33916      20
# 1827  /player-profile/A3785297-69E0-4845-BAB5-0235E6...     29626      20
# 1828  /player-profile/19CD2BAB-6CE5-4ACC-834D-C8C677...     89938      20
# 1829  /player-profile/41C69713-E359-41AC-BC17-3CF2E5...     34706      20
# 1830  /player-profile/7B9A5DF9-EE7E-465D-ADAE-2CB3CB...     22032      20
#
#      Tournaments                                      Confederation  \
# 0             18  category.aspx?id=42511&category=472&ogid=0EB2B...
# 1             14  category.aspx?id=42511&category=472&ogid=DF303...
# 2             22  category.aspx?id=42511&category=472&ogid=DF303...
# 3             22  category.aspx?id=42511&category=472&ogid=0EB2B...
# 4             22  category.aspx?id=42511&category=472&ogid=0EB2B...
# ...          ...                                                ...
# 1826           1  category.aspx?id=42511&category=472&ogid=82A8C...
# 1827           1  category.aspx?id=42511&category=472&ogid=82A8C...
# 1828           1  category.aspx?id=42511&category=472&ogid=82A8C...
# 1829           1  category.aspx?id=42511&category=472&ogid=82A8C...
# 1830           1  category.aspx?id=42511&category=472&ogid=82A8C...
#
#                                                 Country
# 0     category.aspx?id=42511&category=472&ogid=AAAFC...
# 1     category.aspx?id=42511&category=472&ogid=58BCE...
# 2     category.aspx?id=42511&category=472&ogid=58BCE...
# 3     category.aspx?id=42511&category=472&ogid=ED6A6...
# 4     category.aspx?id=42511&category=472&ogid=412A5...
# ...                                                 ...
# 1826  category.aspx?id=42511&category=472&ogid=128ED...
# 1827  category.aspx?id=42511&category=472&ogid=128ED...
# 1828  category.aspx?id=42511&category=472&ogid=128ED...
# 1829  category.aspx?id=42511&category=472&ogid=128ED...
# 1830  category.aspx?id=42511&category=472&ogid=128ED...
#
# [1831 rows x 11 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's Singles URL, Filtered by 100 results on each page.
ms_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this trip to work with the last page which doesn't contain 100 results as the previous ones.
ms_page_number = 1
ms_results = 1831

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
ms_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for ms_page in range(1, ms_page_number + 20):
    if ms_page < 19:  # Pages 1-18 with 100 results on each page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    url = data.find('a')['href'] if data.find('a') else ''
                    individual_row_data.append(url)
                else:
                    individual_row_data.append(data.text.strip())

            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data
            
            if len(ms_df) >= ms_results:
                break
    else:  # Page 19 with less than 100 results on this page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(ms_results - ((ms_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    url = data.find('a')['href'] if data.find('a') else ''
                    individual_row_data.append(url)
                else:
                    individual_row_data.append(data.text.strip())

            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data

            if len(ms_df) >= ms_results:
                break

# Display the resulting DataFrame
ms_df
# Out:
#       Rank x1 x2 Country Code                        Player  \
# 0        1                CHN               [CHN] SHI Yu Qi
# 1        2                DEN          [DEN] Viktor AXELSEN
# 2        3                DEN         [DEN] Anders ANTONSEN
# 3        4                JPN           [JPN] Kodai NARAOKA
# 4        5                MAS             [MAS] LEE Zii Jia
# ...    ... .. ..          ...                           ...
# 1826  1767                UGA    [UGA] Hassan Jamil MAKINDA
# 1827  1767                UGA             [UGA] Latif NGOBI
# 1828  1767                UGA           [UGA] Abaasi BBAALE
# 1829  1767                UGA  [UGA] Preet Nikulkumar PATEL
# 1830  1767                UGA          [UGA] Arafat KALOOBE
#
#                                                      x3 Member ID  Points  \
# 0     /player-profile/38CBD70E-A643-4170-9E6A-288634...     57945  101815
# 1     /player-profile/3BF0C3EA-7BFB-4CC9-A955-3712D8...     25831   93790
# 2     /player-profile/473960FD-334B-476F-9821-8ED939...     91554   84241
# 3     /player-profile/7804BE61-F954-4C46-9E72-FED84B...     62063   84197
# 4     /player-profile/21E9EAF0-5C86-416F-A942-C3ECA0...     81561   83716
# ...                                                 ...       ...     ...
# 1826  /player-profile/7D272D8F-8011-4BB0-AA9E-9C79FE...     33916      20
# 1827  /player-profile/A3785297-69E0-4845-BAB5-0235E6...     29626      20
# 1828  /player-profile/19CD2BAB-6CE5-4ACC-834D-C8C677...     89938      20
# 1829  /player-profile/41C69713-E359-41AC-BC17-3CF2E5...     34706      20
# 1830  /player-profile/7B9A5DF9-EE7E-465D-ADAE-2CB3CB...     22032      20
#
#      Tournaments Confederation   Country
# 0             18          Asia     China
# 1             14        Europe   Denmark
# 2             22        Europe   Denmark
# 3             22          Asia     Japan
# 4             22          Asia  Malaysia
# ...          ...           ...       ...
# 1826           1        Africa    Uganda
# 1827           1        Africa    Uganda
# 1828           1        Africa    Uganda
# 1829           1        Africa    Uganda
# 1830           1        Africa    Uganda
#
# [1831 rows x 11 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's Singles URL, Filtered by 100 results on each page.
ms_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this trip to work with the last page which doesn't contain 100 results as the previous ones.
ms_page_number = 1
ms_results = 1831

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
ms_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for ms_page in range(1, ms_page_number + 20):
    if ms_page < 19:  # Pages 1-18 with 100 results on each page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    url = data.find('a')['href'] if data.find('a') else ''
                    complete_url = 'https://bwf.tournamentsoftware.com' + url if url else ''
                    individual_row_data.append(complete_url)
                else:
                    individual_row_data.append(data.text.strip())

            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data
            
            if len(ms_df) >= ms_results:
                break
    else:  # Page 19 with less than 100 results on this page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(ms_results - ((ms_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    url = data.find('a')['href'] if data.find('a') else ''
                    complete_url = 'https://bwf.tournamentsoftware.com' + url if url else ''
                    individual_row_data.append(complete_url)
                else:
                    individual_row_data.append(data.text.strip())

            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data

            if len(ms_df) >= ms_results:
                break

# Display the resulting DataFrame
ms_df
# Out:
#       Rank x1 x2 Country Code                        Player  \
# 0        1                CHN               [CHN] SHI Yu Qi
# 1        2                DEN          [DEN] Viktor AXELSEN
# 2        3                DEN         [DEN] Anders ANTONSEN
# 3        4                JPN           [JPN] Kodai NARAOKA
# 4        5                MAS             [MAS] LEE Zii Jia
# ...    ... .. ..          ...                           ...
# 1826  1767                UGA    [UGA] Hassan Jamil MAKINDA
# 1827  1767                UGA             [UGA] Latif NGOBI
# 1828  1767                UGA           [UGA] Abaasi BBAALE
# 1829  1767                UGA  [UGA] Preet Nikulkumar PATEL
# 1830  1767                UGA          [UGA] Arafat KALOOBE
#
#                                                      x3 Member ID  Points  \
# 0     https://bwf.tournamentsoftware.com/player-prof...     57945  101815
# 1     https://bwf.tournamentsoftware.com/player-prof...     25831   93790
# 2     https://bwf.tournamentsoftware.com/player-prof...     91554   84241
# 3     https://bwf.tournamentsoftware.com/player-prof...     62063   84197
# 4     https://bwf.tournamentsoftware.com/player-prof...     81561   83716
# ...                                                 ...       ...     ...
# 1826  https://bwf.tournamentsoftware.com/player-prof...     33916      20
# 1827  https://bwf.tournamentsoftware.com/player-prof...     29626      20
# 1828  https://bwf.tournamentsoftware.com/player-prof...     89938      20
# 1829  https://bwf.tournamentsoftware.com/player-prof...     34706      20
# 1830  https://bwf.tournamentsoftware.com/player-prof...     22032      20
#
#      Tournaments Confederation   Country
# 0             18          Asia     China
# 1             14        Europe   Denmark
# 2             22        Europe   Denmark
# 3             22          Asia     Japan
# 4             22          Asia  Malaysia
# ...          ...           ...       ...
# 1826           1        Africa    Uganda
# 1827           1        Africa    Uganda
# 1828           1        Africa    Uganda
# 1829           1        Africa    Uganda
# 1830           1        Africa    Uganda
#
# [1831 rows x 11 columns]

# %%
#ms_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\MS.csv', index = False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's DOuble URL, Filtered by 100 results on each page.
md_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42633&category=474&C474FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this trip to work with the last page which doesn't contain 100 results as the previous ones.
md_page_number = 15
md_results = 1429

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
md_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for md_page in range(1, md_page_number + 1):
    if md_page < 19:  # Pages 1-18 with 100 results on each page
        md_url = md_base_url.format(md_page)
        response = requests.get(md_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    url = data.find_all('a')['href'] if data.find_all('a') else ''
                    complete_url = 'https://bwf.tournamentsoftware.com' + url if url else ''
                    individual_row_data.append(complete_url)
                else:
                    individual_row_data.append(data.text.strip())

            md_df_length = len(md_df)
            md_df.loc[md_df_length] = individual_row_data
            
            if len(md_df) >= md_results:
                break
    else:  # Page 19 with less than 100 results on this page
        md_url = md_base_url.format(md_page)
        response = requests.get(md_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(md_results - ((md_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    url = data.find_all('a')['href'] if data.find_all('a') else ''
                    complete_url = 'https://bwf.tournamentsoftware.com' + url if url else ''
                    individual_row_data.append(complete_url)
                else:
                    individual_row_data.append(data.text.strip())

            md_df_length = len(md_df)
            md_df.loc[md_df_length] = individual_row_data

            if len(md_df) >= md_results:
                break

# Display the resulting DataFrame
md_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 34
#      32 for idx, data in enumerate(row_data):
#      33     if idx == 5:  # The 6th column is 'x3'
# ---> 34         url = data.find_all('a')['href'] if data.find_all('a') else ''
#      35         complete_url = 'https://bwf.tournamentsoftware.com' + url if url else ''
#      36         individual_row_data.append(complete_url)
#
# TypeError: list indices must be integers or slices, not str

# %%
#md_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\MD.csv', index = False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's Singles URL, Filtered by 100 results on each page.
md_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42633&category=474&C474FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this trip to work with the last page which doesn't contain 100 results as the previous ones.
md_page_number = 15
md_results = 1429

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
md_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for md_page in range(1, md_page_number + 1):
    if md_page < 19:  # Pages 1-18 with 100 results on each page
        md_url = md_base_url.format(md_page)
        response = requests.get(md_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    urls = [a['href'] for a in data.find_all('a', href=True)]
                    complete_urls = ', '.join(['https://bwf.tournamentsoftware.com' + url for url in urls])
                    individual_row_data.append(complete_urls)
                else:
                    individual_row_data.append(data.text.strip())

            md_df_length = len(md_df)
            md_df.loc[md_df_length] = individual_row_data
            
            if len(md_df) >= md_results:
                break
    else:  # Page 19 with less than 100 results on this page
        md_url = md_base_url.format(md_page)
        response = requests.get(md_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(md_results - ((md_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    urls = [a['href'] for a in data.find_all('a', href=True)]
                    complete_urls = ', '.join(['https://bwf.tournamentsoftware.com' + url for url in urls])
                    individual_row_data.append(complete_urls)
                else:
                    individual_row_data.append(data.text.strip())

            md_df_length = len(md_df)
            md_df.loc[md_df_length] = individual_row_data

            if len(md_df) >= md_results:
                break

# Display the resulting DataFrame
md_df
# Out:
#       Rank x1 x2 Country Code                                          Player  \
# 0        1             CHNCHN            [CHN] LIANG Wei Keng[CHN] WANG Chang
# 1        2             DENDEN  [DEN] Kim ASTRUP[DEN] Anders Skaarup RASMUSSEN
# 2        3             KORKOR          [KOR] KANG Min Hyuk[KOR] SEO Seung Jae
# 3        4             MASMAS              [MAS] Aaron CHIA[MAS] SOH Wooi Yik
# 4        5             CHNCHN              [CHN] HE Ji Ting[CHN] REN Xiang Yu
# ...    ... .. ..          ...                                             ...
# 1424  1415             ESPESP       [ESP] Fernando CIVICO[ESP] Ricardo RETTIG
# 1425  1426             BELBEL         [BEL] Elias BRACKE[BEL] Senne HOUTHOOFD
# 1426  1427             BELBEL         [BEL] Charles FOUYN[BEL] Baptiste ROLIN
# 1427  1427             FIJFIJ               [FIJ] Jared CHUNG[FIJ] Robert LOO
# 1428  1427             COKCOK          [COK] Brendan LEE[COK] Emanuela MATAIO
#
#                                                      x3   Member ID Points  \
# 0     https://bwf.tournamentsoftware.com/player-prof...  9053155414  96798
# 1     https://bwf.tournamentsoftware.com/player-prof...  9298044414  91753
# 2     https://bwf.tournamentsoftware.com/player-prof...  7726266513  90415
# 3     https://bwf.tournamentsoftware.com/player-prof...  5620399389  84315
# 4     https://bwf.tournamentsoftware.com/player-prof...  5967384812  83961
# ...                                                 ...         ...    ...
# 1424  https://bwf.tournamentsoftware.com/player-prof...  9632969882     20
# 1425  https://bwf.tournamentsoftware.com/player-prof...  6725155858     15
# 1426  https://bwf.tournamentsoftware.com/player-prof...  9970396561      2
# 1427  https://bwf.tournamentsoftware.com/player-prof...  8267255618      2
# 1428  https://bwf.tournamentsoftware.com/player-prof...  1988993996      2
#
#      Tournaments Confederation       Country
# 0             14          Asia         China
# 1             20        Europe       Denmark
# 2             20          Asia         Korea
# 3             16          Asia      Malaysia
# 4             23          Asia         China
# ...          ...           ...           ...
# 1424           1        Europe         Spain
# 1425           1        Europe       Belgium
# 1426           1        Europe       Belgium
# 1427           1       Oceania          Fiji
# 1428           1       Oceania  COOK ISLANDS
#
# [1429 rows x 11 columns]

# %%
md_df.to_csv(r'C:\Users\Minh.Nguyen\OneDrive - Stats Perform\_badminton - WORLD - BWF\MD.csv', index = False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's Singles URL, Filtered by 100 results on each page.
ms_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results.
# We need this trip to work with the last page which doesn't contain 100 results as the previous ones.
ms_page_number = 1
ms_results = 1831

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
md_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for md_page in range(1, md_page_number + 20):
    if md_page < 19:  # Pages 1-18 with 100 results on each page
        md_url = md_base_url.format(md_page)
        response = requests.get(md_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    urls = [a['href'] for a in data.find_all('a', href=True)]
                    complete_urls = ', '.join(['https://bwf.tournamentsoftware.com' + url for url in urls])
                    individual_row_data.append(complete_urls)
                elif idx == 6:  # The 7th column is 'Member ID'
                    texts = [text for text in data.stripped_strings]
                    concatenated_texts = '/'.join(texts)
                    individual_row_data.append(concatenated_texts)
                else:
                    individual_row_data.append(data.text.strip())

            md_df_length = len(md_df)
            md_df.loc[md_df_length] = individual_row_data
            
            if len(md_df) >= md_results:
                break
    else:  # Page 19 with less than 100 results on this page
        md_url = md_base_url.format(md_page)
        response = requests.get(md_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(md_results - ((md_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    urls = [a['href'] for a in data.find_all('a', href=True)]
                    complete_urls = ', '.join(['https://bwf.tournamentsoftware.com' + url for url in urls])
                    individual_row_data.append(complete_urls)
                elif idx == 6:  # The 7th column is 'Member ID'
                    texts = [text for text in data.stripped_strings]
                    concatenated_texts = '/'.join(texts)
                    individual_row_data.append(concatenated_texts)
                else:
                    individual_row_data.append(data.text.strip())

            md_df_length = len(md_df)
            md_df.loc[md_df_length] = individual_row_data

            if len(md_df) >= md_results:
                break

# Display the resulting DataFrame
md_df
# Out:
#       Rank x1 x2 Country Code                                          Player  \
# 0        1             CHNCHN            [CHN] LIANG Wei Keng[CHN] WANG Chang
# 1        2             DENDEN  [DEN] Kim ASTRUP[DEN] Anders Skaarup RASMUSSEN
# 2        3             KORKOR          [KOR] KANG Min Hyuk[KOR] SEO Seung Jae
# 3        4             MASMAS              [MAS] Aaron CHIA[MAS] SOH Wooi Yik
# 4        5             CHNCHN              [CHN] HE Ji Ting[CHN] REN Xiang Yu
# ...    ... .. ..          ...                                             ...
# 1424  1415             ESPESP       [ESP] Fernando CIVICO[ESP] Ricardo RETTIG
# 1425  1426             BELBEL         [BEL] Elias BRACKE[BEL] Senne HOUTHOOFD
# 1426  1427             BELBEL         [BEL] Charles FOUYN[BEL] Baptiste ROLIN
# 1427  1427             FIJFIJ               [FIJ] Jared CHUNG[FIJ] Robert LOO
# 1428  1427             COKCOK          [COK] Brendan LEE[COK] Emanuela MATAIO
#
#                                                      x3    Member ID Points  \
# 0     https://bwf.tournamentsoftware.com/player-prof...  90531/55414  96798
# 1     https://bwf.tournamentsoftware.com/player-prof...  92980/44414  91753
# 2     https://bwf.tournamentsoftware.com/player-prof...  77262/66513  90415
# 3     https://bwf.tournamentsoftware.com/player-prof...  56203/99389  84315
# 4     https://bwf.tournamentsoftware.com/player-prof...  59673/84812  83961
# ...                                                 ...          ...    ...
# 1424  https://bwf.tournamentsoftware.com/player-prof...  96329/69882     20
# 1425  https://bwf.tournamentsoftware.com/player-prof...  67251/55858     15
# 1426  https://bwf.tournamentsoftware.com/player-prof...  99703/96561      2
# 1427  https://bwf.tournamentsoftware.com/player-prof...  82672/55618      2
# 1428  https://bwf.tournamentsoftware.com/player-prof...  19889/93996      2
#
#      Tournaments Confederation       Country
# 0             14          Asia         China
# 1             20        Europe       Denmark
# 2             20          Asia         Korea
# 3             16          Asia      Malaysia
# 4             23          Asia         China
# ...          ...           ...           ...
# 1424           1        Europe         Spain
# 1425           1        Europe       Belgium
# 1426           1        Europe       Belgium
# 1427           1       Oceania          Fiji
# 1428           1       Oceania  COOK ISLANDS
#
# [1429 rows x 11 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Men's Singles URL, Filtered by 100 results on each page.
ms_base_url = 'https://bwf.tournamentsoftware.com/ranking/category.aspx?id=42511&category=472&C472FOC=&p={}&ps=100'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# After checking with the filter by 100 results on each page. There are a total of 19 pages and 1831 results. 
# We need this information to work with the last page which contains less than 100 results compared to the previous pages.
ms_page_number = 19
ms_results = 1831

# Create DataFrame
list_of_columns = ['Rank', 'x1', 'x2', 'Country Code', 'Player', 'x3', 'Member ID', 'Points', 'Tournaments', 'Confederation', 'Country']
ms_df = pd.DataFrame(columns=list_of_columns)

# Create a loop to add data to all pages in DataFrame
# Loop through pages 1 to 19
for ms_page in range(1, ms_page_number + 1):
    if ms_page < 19:  # Pages 1-18 with 100 results on each page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:102]  # Skip the header rows

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    urls = [a['href'] for a in data.find_all('a', href=True)]
                    complete_urls = ', '.join(['https://bwf.tournamentsoftware.com' + url for url in urls])
                    individual_row_data.append(complete_urls)
                elif idx == 6:  # The 7th column is 'Member ID'
                    texts = [text for text in data.stripped_strings]
                    concatenated_texts = '/'.join(texts)
                    individual_row_data.append(concatenated_texts)
                else:
                    individual_row_data.append(data.text.strip())

            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data
            
            if len(ms_df) >= ms_results:
                break
    else:  # Page 19 with less than 100 results on this page
        ms_url = ms_base_url.format(ms_page)
        response = requests.get(ms_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        ranking_table = soup.find('table', class_='ruler')
        all_rows = ranking_table.find_all('tr')[2:(ms_results - ((ms_page_number - 1) * 100) + 2)]

        for row in all_rows:
            row_data = row.find_all('td')
            individual_row_data = []

            for idx, data in enumerate(row_data):
                if idx == 5:  # The 6th column is 'x3'
                    urls = [a['href'] for a in data.find_all('a', href=True)]
                    complete_urls = ', '.join(['https://bwf.tournamentsoftware.com' + url for url in urls])
                    individual_row_data.append(complete_urls)
                elif idx == 6:  # The 7th column is 'Member ID'
                    texts = [text for text in data.stripped_strings]
                    concatenated_texts = '/'.join(texts)
                    individual_row_data.append(concatenated_texts)
                else:
                    individual_row_data.append(data.text.strip())

            ms_df_length = len(ms_df)
            ms_df.loc[ms_df_length] = individual_row_data

            if len(ms_df) >= ms_results:
                break

# Display the resulting DataFrame
ms_df
# Out:
#       Rank x1 x2 Country Code                        Player  \
# 0        1                CHN               [CHN] SHI Yu Qi
# 1        2                DEN          [DEN] Viktor AXELSEN
# 2        3                DEN         [DEN] Anders ANTONSEN
# 3        4                JPN           [JPN] Kodai NARAOKA
# 4        5                MAS             [MAS] LEE Zii Jia
# ...    ... .. ..          ...                           ...
# 1826  1767                UGA    [UGA] Hassan Jamil MAKINDA
# 1827  1767                UGA             [UGA] Latif NGOBI
# 1828  1767                UGA           [UGA] Abaasi BBAALE
# 1829  1767                UGA  [UGA] Preet Nikulkumar PATEL
# 1830  1767                UGA          [UGA] Arafat KALOOBE
#
#                                                      x3 Member ID  Points  \
# 0     https://bwf.tournamentsoftware.com/player-prof...     57945  101815
# 1     https://bwf.tournamentsoftware.com/player-prof...     25831   93790
# 2     https://bwf.tournamentsoftware.com/player-prof...     91554   84241
# 3     https://bwf.tournamentsoftware.com/player-prof...     62063   84197
# 4     https://bwf.tournamentsoftware.com/player-prof...     81561   83716
# ...                                                 ...       ...     ...
# 1826  https://bwf.tournamentsoftware.com/player-prof...     33916      20
# 1827  https://bwf.tournamentsoftware.com/player-prof...     29626      20
# 1828  https://bwf.tournamentsoftware.com/player-prof...     89938      20
# 1829  https://bwf.tournamentsoftware.com/player-prof...     34706      20
# 1830  https://bwf.tournamentsoftware.com/player-prof...     22032      20
#
#      Tournaments Confederation   Country
# 0             18          Asia     China
# 1             14        Europe   Denmark
# 2             22        Europe   Denmark
# 3             22          Asia     Japan
# 4             22          Asia  Malaysia
# ...          ...           ...       ...
# 1826           1        Africa    Uganda
# 1827           1        Africa    Uganda
# 1828           1        Africa    Uganda
# 1829           1        Africa    Uganda
# 1830           1        Africa    Uganda
#
# [1831 rows x 11 columns]
